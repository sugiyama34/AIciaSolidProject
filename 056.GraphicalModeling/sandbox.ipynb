# %%
import numpy as np
import os
import pandas as pd
from scipy.stats import chi2

pd.options.display.float_format = '{:.4f}'.format

# %%
df = pd.read_csv(os.path.join('..', 'data', '12_subject_scores.csv'))

df.head()
# Out:
#          国語        英語        数学        物理        化学        生物        地学  \
# 0 -0.394296 -0.863552  0.299784  0.052264 -0.193747  1.762086 -0.458840
# 1 -1.062188 -0.061273 -0.572619 -0.544283 -0.305108  1.988985 -0.166363
# 2 -0.669470 -0.751437  0.574793 -0.379771 -0.539259 -0.623499 -1.034320
# 3  0.776026  1.166164 -0.986413 -0.723857 -0.091960 -0.150870 -0.047286
# 4 -2.212173 -0.571762 -0.842556 -0.849638 -0.280362 -1.089733 -0.836957
#
#         世界史       日本史        経済        地理        倫理
# 0 -0.889665 -0.163093 -0.939310 -0.149300 -2.286900
# 1  0.610966 -0.951714  1.390854 -0.226003 -0.031098
# 2  0.393436  1.439274  2.218160  0.716289 -0.462702
# 3 -2.427921  0.433994 -1.270779  0.323981  1.406393
# 4 -0.812882 -1.702264 -0.365675 -0.113076 -2.497812

# %%
cor_inv = np.linalg.inv(df.corr())
sqrt_diag_inv = np.diag(1/np.sqrt(np.diag(cor_inv)))

cor_inv_std = sqrt_diag_inv.dot(cor_inv).dot(sqrt_diag_inv)

# %%
pd.DataFrame(cor_inv_std, index=df.columns, columns=df.columns)
# Out:
#            国語        英語        数学        物理        化学        生物        地学  \
# 国語   1.000000 -0.217951 -0.019185 -0.102306 -0.082707  0.009664  0.007089
# 英語  -0.217951  1.000000 -0.021446 -0.027383 -0.048900 -0.018640 -0.014234
# 数学  -0.019185 -0.021446  1.000000 -0.328966 -0.074756 -0.060503  0.025255
# 物理  -0.102306 -0.027383 -0.328966  1.000000 -0.053275 -0.023651 -0.087571
# 化学  -0.082707 -0.048900 -0.074756 -0.053275  1.000000 -0.178026 -0.224728
# 生物   0.009664 -0.018640 -0.060503 -0.023651 -0.178026  1.000000 -0.270631
# 地学   0.007089 -0.014234  0.025255 -0.087571 -0.224728 -0.270631  1.000000
# 世界史 -0.064580  0.011057 -0.016956  0.003528  0.011185 -0.017174 -0.025806
# 日本史 -0.091774 -0.017024 -0.005833  0.040766 -0.009157  0.054296 -0.043757
# 経済  -0.073937  0.041023  0.022023  0.028570  0.084876 -0.143267 -0.113982
# 地理   0.022149 -0.084418  0.026759 -0.071625  0.022616  0.003038  0.022746
# 倫理  -0.170930 -0.232535 -0.023335  0.001497  0.014115 -0.153239 -0.129605
#
#           世界史       日本史        経済        地理        倫理
# 国語  -0.064580 -0.091774 -0.073937  0.022149 -0.170930
# 英語   0.011057 -0.017024  0.041023 -0.084418 -0.232535
# 数学  -0.016956 -0.005833  0.022023  0.026759 -0.023335
# 物理   0.003528  0.040766  0.028570 -0.071625  0.001497
# 化学   0.011185 -0.009157  0.084876  0.022616  0.014115
# 生物  -0.017174  0.054296 -0.143267  0.003038 -0.153239
# 地学  -0.025806 -0.043757 -0.113982  0.022746 -0.129605
# 世界史  1.000000 -0.249001 -0.065679 -0.257794 -0.022659
# 日本史 -0.249001  1.000000 -0.023919 -0.221817 -0.042064
# 経済  -0.065679 -0.023919  1.000000 -0.074519 -0.190453
# 地理  -0.257794 -0.221817 -0.074519  1.000000 -0.015406
# 倫理  -0.022659 -0.042064 -0.190453 -0.015406  1.000000

# %%
df_cor = pd.read_csv(os.path.join('..', 'data', 'cor.csv'))
df_cor = df_cor.drop(['Unnamed: 0', '公開日時', 'ln_経過日数', 'ln_視聴回数', 'ln_高評価件数'], axis=1).drop([1, 8, 9, 10])

# %%
df_cor
# Out:
#    動画時間_correct      経過日数    プレミア公開      視聴回数      コメント     高評価件数     低評価件数
# 0      1.000000 -0.472549  0.677808  0.328936  0.452101  0.410099  0.125069
# 2     -0.472549  1.000000 -0.641806  0.127134 -0.077394  0.009461  0.258704
# 3      0.677808 -0.641806  1.000000  0.214025  0.377556  0.329272  0.164930
# 4      0.328936  0.127134  0.214025  1.000000  0.848600  0.910386  0.831124
# 5      0.452101 -0.077394  0.377556  0.848600  1.000000  0.832235  0.613678
# 6      0.410099  0.009461  0.329272  0.910386  0.832235  1.000000  0.660566
# 7      0.125069  0.258704  0.164930  0.831124  0.613678  0.660566  1.000000

# %%
np.linalg.inv(df_cor)
# Out:
# array([[ 2.28299745,  0.09554208, -1.39671209, -1.54582759, -0.08868323,
#          0.30513158,  1.05774927],
#        [ 0.09554208,  2.28084045,  1.58770752,  0.77297079,  0.07875049,
#         -0.57810342, -1.17275994],
#        [-1.39671209,  1.58770752,  3.42421525,  3.46215998, -0.80247796,
#         -1.68423396, -2.07329247],
#        [-1.54582759,  0.77297079,  3.46215998, 19.74502081, -4.58243276,
#         -9.42255889, -7.95186004],
#        [-0.08868323,  0.07875049, -0.80247796, -4.58243276,  4.68277739,
#         -0.22063529,  1.20366977],
#        [ 0.30513158, -0.57810342, -1.68423396, -9.42255889, -0.22063529,
#          8.29778775,  2.87465815],
#        [ 1.05774927, -1.17275994, -2.07329247, -7.95186004,  1.20366977,
#          2.87465815,  5.48447308]])

# %%
df_cor.shape
# Out:
# (7, 7)

# %%
cor_inv = np.linalg.inv(df_cor)
sqrt_diag_inv = np.diag(1/np.sqrt(np.diag(cor_inv)))

cor_inv_std = sqrt_diag_inv.dot(cor_inv).dot(sqrt_diag_inv)

# %%
pd.DataFrame(cor_inv_std, index=df_cor.columns, columns=df_cor.columns)
# Out:
#               動画時間_correct      経過日数    プレミア公開      視聴回数      コメント     高評価件数  \
# 動画時間_correct      1.000000  0.041869 -0.499544 -0.230239 -0.027123  0.070106
# 経過日数              0.041869  1.000000  0.568123  0.115183  0.024097 -0.132885
# プレミア公開           -0.499544  0.568123  1.000000  0.421054 -0.200401 -0.315966
# 視聴回数             -0.230239  0.115183  0.421054  1.000000 -0.476558 -0.736137
# コメント             -0.027123  0.024097 -0.200401 -0.476558  1.000000 -0.035395
# 高評価件数             0.070106 -0.132885 -0.315966 -0.736137 -0.035395  1.000000
# 低評価件数             0.298925 -0.331584 -0.478424 -0.764139  0.237513  0.426126
#
#                  低評価件数
# 動画時間_correct  0.298925
# 経過日数         -0.331584
# プレミア公開       -0.478424
# 視聴回数         -0.764139
# コメント          0.237513
# 高評価件数         0.426126
# 低評価件数         1.000000

# %%
pd.DataFrame(cor_inv_std, index=df_cor.columns, columns=df_cor.columns).applymap(lambda x: -x/np.sqrt(1+x**2) if x < 1 else 1)
# Out:
#               動画時間_correct      経過日数    プレミア公開      視聴回数      コメント     高評価件数  \
# 動画時間_correct      1.000000 -0.041833  0.446887  0.224369  0.027113 -0.069934
# 経過日数             -0.041833  1.000000 -0.493971 -0.114426 -0.024090  0.131727
# プレミア公開            0.446887 -0.493971  1.000000 -0.388058  0.196495  0.301285
# 視聴回数              0.224369 -0.114426 -0.388058  1.000000  0.430204  0.592831
# コメント              0.027113 -0.024090  0.196495  0.430204  1.000000  0.035373
# 高評価件数            -0.069934  0.131727  0.301285  0.592831  0.035373  1.000000
# 低評価件数            -0.286403  0.314733  0.431575  0.607166 -0.231085 -0.392018
#
#                  低評価件数
# 動画時間_correct -0.286403
# 経過日数          0.314733
# プレミア公開        0.431575
# 視聴回数          0.607166
# コメント         -0.231085
# 高評価件数        -0.392018
# 低評価件数         1.000000

# %%
def inverse_cor(cor):
    cor_inv = np.linalg.inv(cor)
    diag = np.diag(1/np.sqrt(np.diag(cor_inv)))
    return diag.dot(cor_inv).dot(diag)

# %%
def estimate(sample_cor, cond_ind_pairs, error_torelance=1e-4):
    dim = sample_cor.shape[0]
    sample_cor = np.array(sample_cor)
    
    estimated_cor = sample_cor.copy()
    
#     print('========', 'dim', '========')
#     print(dim)
#     print('========', 'estimated_cor', '========')
#     print(estimated_cor)
    
    error = 1
    
#     print('========', 'error', '========')
#     print(error)
    
    counter = 0
    
    while error > error_torelance:
        print('========', counter, '-th iteration', '========')
        counter = counter + 1
        
        estimated_cor_before = estimated_cor.copy()
        for i, j in cond_ind_pairs:
            print('    ', '========', i, j, '========')
            estimated_cor_inv = np.linalg.inv(estimated_cor)
            new_ij = estimated_cor[i][j] + estimated_cor_inv[i][j]/(estimated_cor_inv[i][i] * estimated_cor_inv[j][j] - estimated_cor_inv[i][j]**2)
            estimated_cor[i][j] = new_ij
            estimated_cor[j][i] = new_ij
        
        error = np.abs(estimated_cor - estimated_cor_before).max().max()
    
    return estimated_cor


estimated_cor = estimate(df_cor.values, [(1, 4), ])

print('========', 'original', '========')
df_original = pd.DataFrame(df_cor.values, index=df_cor.columns, columns=df_cor.columns)
display(df_original)

print('========', 'estimated', '========')
df_estimated = pd.DataFrame(estimated_cor, index=df_cor.columns, columns=df_cor.columns)
display(df_estimated)

pd.DataFrame(inverse_cor(estimated_cor), index=df_cor.columns, columns=df_cor.columns)
# Out:
# ======== 0 -th iteration ========
#      ======== 1 4 ========
# ======== 1 -th iteration ========
#      ======== 1 4 ========
# ======== original ========
#               動画時間_correct    経過日数  プレミア公開   視聴回数    コメント  高評価件数  低評価件数
# 動画時間_correct        1.0000 -0.4725  0.6778 0.3289  0.4521 0.4101 0.1251
# 経過日数               -0.4725  1.0000 -0.6418 0.1271 -0.0774 0.0095 0.2587
# プレミア公開              0.6778 -0.6418  1.0000 0.2140  0.3776 0.3293 0.1649
# 視聴回数                0.3289  0.1271  0.2140 1.0000  0.8486 0.9104 0.8311
# コメント                0.4521 -0.0774  0.3776 0.8486  1.0000 0.8322 0.6137
# 高評価件数               0.4101  0.0095  0.3293 0.9104  0.8322 1.0000 0.6606
# 低評価件数               0.1251  0.2587  0.1649 0.8311  0.6137 0.6606 1.0000
# ======== estimated ========
#               動画時間_correct    経過日数  プレミア公開   視聴回数    コメント  高評価件数  低評価件数
# 動画時間_correct        1.0000 -0.4725  0.6778 0.3289  0.4521 0.4101 0.1251
# 経過日数               -0.4725  1.0000 -0.6418 0.1271 -0.0700 0.0095 0.2587
# プレミア公開              0.6778 -0.6418  1.0000 0.2140  0.3776 0.3293 0.1649
# 視聴回数                0.3289  0.1271  0.2140 1.0000  0.8486 0.9104 0.8311
# コメント                0.4521 -0.0700  0.3776 0.8486  1.0000 0.8322 0.6137
# 高評価件数               0.4101  0.0095  0.3293 0.9104  0.8322 1.0000 0.6606
# 低評価件数               0.1251  0.2587  0.1649 0.8311  0.6137 0.6606 1.0000
#               動画時間_correct    経過日数  プレミア公開    視聴回数    コメント   高評価件数   低評価件数
# 動画時間_correct        1.0000  0.0425 -0.4975 -0.2293 -0.0281  0.0701  0.2979
# 経過日数                0.0425  1.0000  0.5715  0.1265 -0.0000 -0.1321 -0.3368
# プレミア公開             -0.4975  0.5715  1.0000  0.4264 -0.2135 -0.3153 -0.4811
# 視聴回数               -0.2293  0.1265  0.4264  1.0000 -0.4788 -0.7366 -0.7661
# コメント               -0.0281 -0.0000 -0.2135 -0.4788  1.0000 -0.0322  0.2451
# 高評価件数               0.0701 -0.1321 -0.3153 -0.7366 -0.0322  1.0000  0.4258
# 低評価件数               0.2979 -0.3368 -0.4811 -0.7661  0.2451  0.4258  1.0000

# %%
estimate(df_cor.values, [])
# Out:
# ======== 0 -th iteration ========
# array([[ 1.        , -0.47254902,  0.67780803,  0.32893588,  0.45210133,
#          0.41009853,  0.12506886],
#        [-0.47254902,  1.        , -0.64180632,  0.12713391, -0.07739371,
#          0.00946105,  0.25870422],
#        [ 0.67780803, -0.64180632,  1.        ,  0.21402474,  0.37755638,
#          0.32927192,  0.16493   ],
#        [ 0.32893588,  0.12713391,  0.21402474,  1.        ,  0.84860022,
#          0.91038564,  0.83112448],
#        [ 0.45210133, -0.07739371,  0.37755638,  0.84860022,  1.        ,
#          0.83223479,  0.61367802],
#        [ 0.41009853,  0.00946105,  0.32927192,  0.91038564,  0.83223479,
#          1.        ,  0.66056598],
#        [ 0.12506886,  0.25870422,  0.16493   ,  0.83112448,  0.61367802,
#          0.66056598,  1.        ]])

# %%
chi2.cdf(0, 1)
# Out:
# 0.0

# %%
chi2.cdf(10, 1)
# Out:
# 0.9984345977419975

# %%
def deviance_and_p(original_cor, estimated_cor, df):
    dim = original_cor.shape[0]
    dev = dim * (np.log(np.linalg.det(estimated_cor)) - np.log(np.linalg.det(original_cor)))
    p = chi2.cdf(dev, df)
    
    return dev, p

# %%
deviance_and_p(df_cor.values, estimated_cor, df=1)
# Out:
# (0.004065670967228208, 0.0508407527843253)

# %% [markdown]
# ## Do Graphical Modeling

# %%
print('inverse of correlation')
pd.DataFrame(inverse_cor(df_cor.values), index=df_cor.columns, columns=df_cor.columns)
# Out:
# inverse of correlation
#               動画時間_correct    経過日数  プレミア公開    視聴回数    コメント   高評価件数   低評価件数
# 動画時間_correct        1.0000  0.0419 -0.4995 -0.2302 -0.0271  0.0701  0.2989
# 経過日数                0.0419  1.0000  0.5681  0.1152  0.0241 -0.1329 -0.3316
# プレミア公開             -0.4995  0.5681  1.0000  0.4211 -0.2004 -0.3160 -0.4784
# 視聴回数               -0.2302  0.1152  0.4211  1.0000 -0.4766 -0.7361 -0.7641
# コメント               -0.0271  0.0241 -0.2004 -0.4766  1.0000 -0.0354  0.2375
# 高評価件数               0.0701 -0.1329 -0.3160 -0.7361 -0.0354  1.0000  0.4261
# 低評価件数               0.2989 -0.3316 -0.4784 -0.7641  0.2375  0.4261  1.0000

# %%
cond_ind_pairs = [(1, 4), ]
estimated_cors = [df_cor.values]

estimated_cors.append(estimate(estimated_cors[-1], cond_ind_pairs))

print('========', 'original', '========')
df_original = pd.DataFrame(estimated_cors[0], index=df_cor.columns, columns=df_cor.columns)
display(df_original)

print('========', 'estimated', '========')
df_estimated = pd.DataFrame(estimated_cors[-1], index=df_cor.columns, columns=df_cor.columns)
display(df_estimated)


print('========', 'test rel to original', '========')
dev, p = deviance_and_p(estimated_cors[0], estimated_cors[-1], df=len(cond_ind_pairs))
print('dev:', dev)
print('p:', 1 - p)

print('========', 'test rel to prev', '========')
dev, p = deviance_and_p(estimated_cors[-2], estimated_cors[-1], df=1)
print('dev:', dev)
print('p:', 1 - p)
# Out:
# ======== 0 -th iteration ========
#      ======== 1 4 ========
# ======== 1 -th iteration ========
#      ======== 1 4 ========
# ======== original ========
#               動画時間_correct    経過日数  プレミア公開   視聴回数    コメント  高評価件数  低評価件数
# 動画時間_correct        1.0000 -0.4725  0.6778 0.3289  0.4521 0.4101 0.1251
# 経過日数               -0.4725  1.0000 -0.6418 0.1271 -0.0774 0.0095 0.2587
# プレミア公開              0.6778 -0.6418  1.0000 0.2140  0.3776 0.3293 0.1649
# 視聴回数                0.3289  0.1271  0.2140 1.0000  0.8486 0.9104 0.8311
# コメント                0.4521 -0.0774  0.3776 0.8486  1.0000 0.8322 0.6137
# 高評価件数               0.4101  0.0095  0.3293 0.9104  0.8322 1.0000 0.6606
# 低評価件数               0.1251  0.2587  0.1649 0.8311  0.6137 0.6606 1.0000
# ======== estimated ========
#               動画時間_correct    経過日数  プレミア公開   視聴回数    コメント  高評価件数  低評価件数
# 動画時間_correct        1.0000 -0.4725  0.6778 0.3289  0.4521 0.4101 0.1251
# 経過日数               -0.4725  1.0000 -0.6418 0.1271 -0.0700 0.0095 0.2587
# プレミア公開              0.6778 -0.6418  1.0000 0.2140  0.3776 0.3293 0.1649
# 視聴回数                0.3289  0.1271  0.2140 1.0000  0.8486 0.9104 0.8311
# コメント                0.4521 -0.0700  0.3776 0.8486  1.0000 0.8322 0.6137
# 高評価件数               0.4101  0.0095  0.3293 0.9104  0.8322 1.0000 0.6606
# 低評価件数               0.1251  0.2587  0.1649 0.8311  0.6137 0.6606 1.0000
# ======== test rel to original ========
# dev: 0.004065670967228208
# p: 0.9491592472156747
# ======== test rel to prev ========
# dev: 0.004065670967228208
# p: 0.9491592472156747

# %%
pd.DataFrame(inverse_cor(estimated_cor), index=df_cor.columns, columns=df_cor.columns)
# Out:
#               動画時間_correct    経過日数  プレミア公開    視聴回数    コメント   高評価件数   低評価件数
# 動画時間_correct        1.0000  0.0425 -0.4975 -0.2293 -0.0281  0.0701  0.2979
# 経過日数                0.0425  1.0000  0.5715  0.1265 -0.0000 -0.1321 -0.3368
# プレミア公開             -0.4975  0.5715  1.0000  0.4264 -0.2135 -0.3153 -0.4811
# 視聴回数               -0.2293  0.1265  0.4264  1.0000 -0.4788 -0.7366 -0.7661
# コメント               -0.0281 -0.0000 -0.2135 -0.4788  1.0000 -0.0322  0.2451
# 高評価件数               0.0701 -0.1321 -0.3153 -0.7366 -0.0322  1.0000  0.4258
# 低評価件数               0.2979 -0.3368 -0.4811 -0.7661  0.2451  0.4258  1.0000

# %%
cond_ind_pairs = [(1, 4), (4, 5)]
# estimated_cors = [df_cor.values]

estimated_cors.append(estimate(estimated_cors[-1], cond_ind_pairs))

print('========', 'original', '========')
df_original = pd.DataFrame(estimated_cors[0], index=df_cor.columns, columns=df_cor.columns)
display(df_original)

print('========', 'estimated', '========')
df_estimated = pd.DataFrame(estimated_cors[-1], index=df_cor.columns, columns=df_cor.columns)
display(df_estimated)


print('========', 'test rel to original', '========')
dev, p = deviance_and_p(estimated_cors[0], estimated_cors[-1], df=len(cond_ind_pairs))
print('dev:', dev)
print('p:', 1 - p)

print('========', 'test rel to prev', '========')
dev, p = deviance_and_p(estimated_cors[-2], estimated_cors[-1], df=1)
print('dev:', dev)
print('p:', 1 - p)
# Out:
# ======== 0 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
# ======== 1 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
# ======== 2 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
# ======== original ========
#               動画時間_correct    経過日数  プレミア公開   視聴回数    コメント  高評価件数  低評価件数
# 動画時間_correct        1.0000 -0.4725  0.6778 0.3289  0.4521 0.4101 0.1251
# 経過日数               -0.4725  1.0000 -0.6418 0.1271 -0.0774 0.0095 0.2587
# プレミア公開              0.6778 -0.6418  1.0000 0.2140  0.3776 0.3293 0.1649
# 視聴回数                0.3289  0.1271  0.2140 1.0000  0.8486 0.9104 0.8311
# コメント                0.4521 -0.0774  0.3776 0.8486  1.0000 0.8322 0.6137
# 高評価件数               0.4101  0.0095  0.3293 0.9104  0.8322 1.0000 0.6606
# 低評価件数               0.1251  0.2587  0.1649 0.8311  0.6137 0.6606 1.0000
# ======== estimated ========
#               動画時間_correct    経過日数  プレミア公開   視聴回数    コメント  高評価件数  低評価件数
# 動画時間_correct        1.0000 -0.4725  0.6778 0.3289  0.4521 0.4101 0.1251
# 経過日数               -0.4725  1.0000 -0.6418 0.1271 -0.0713 0.0095 0.2587
# プレミア公開              0.6778 -0.6418  1.0000 0.2140  0.3776 0.3293 0.1649
# 視聴回数                0.3289  0.1271  0.2140 1.0000  0.8486 0.9104 0.8311
# コメント                0.4521 -0.0713  0.3776 0.8486  1.0000 0.8270 0.6137
# 高評価件数               0.4101  0.0095  0.3293 0.9104  0.8270 1.0000 0.6606
# 低評価件数               0.1251  0.2587  0.1649 0.8311  0.6137 0.6606 1.0000
# ======== test rel to original ========
# dev: 0.01145897276796859
# p: 0.9942868958209885
# ======== test rel to prev ========
# dev: 0.007393301800740382
# p: 0.9314788887510864

# %%
print('inverse of correlation')
pd.DataFrame(inverse_cor(estimated_cors[-1]), index=df_cor.columns, columns=df_cor.columns)
# Out:
# inverse of correlation
#               動画時間_correct    経過日数  プレミア公開    視聴回数    コメント   高評価件数   低評価件数
# 動画時間_correct        1.0000  0.0425 -0.4970 -0.2273 -0.0257  0.0692  0.2972
# 経過日数                0.0425  1.0000  0.5705  0.1251 -0.0000 -0.1322 -0.3357
# プレミア公開             -0.4970  0.5705  1.0000  0.4298 -0.2211 -0.3218 -0.4835
# 視聴回数               -0.2273  0.1251  0.4298  1.0000 -0.4969 -0.7438 -0.7669
# コメント               -0.0257 -0.0000 -0.2211 -0.4969  1.0000  0.0000  0.2569
# 高評価件数               0.0692 -0.1322 -0.3218 -0.7438  0.0000  1.0000  0.4326
# 低評価件数               0.2972 -0.3357 -0.4835 -0.7669  0.2569  0.4326  1.0000

# %%
cond_ind_pairs = [(1, 4), (4, 5), (0, 1)]
# estimated_cors = [df_cor.values]

estimated_cors.append(estimate(estimated_cors[-1], cond_ind_pairs))

print('========', 'original', '========')
df_original = pd.DataFrame(estimated_cors[0], index=df_cor.columns, columns=df_cor.columns)
display(df_original)

print('========', 'estimated', '========')
df_estimated = pd.DataFrame(estimated_cors[-1], index=df_cor.columns, columns=df_cor.columns)
display(df_estimated)


print('========', 'test rel to original', '========')
dev, p = deviance_and_p(estimated_cors[0], estimated_cors[-1], df=len(cond_ind_pairs))
print('dev:', dev)
print('p:', 1- p)

print('========', 'test rel to prev', '========')
dev, p = deviance_and_p(estimated_cors[-2], estimated_cors[-1], df=1)
print('dev:', dev)
print('p:', 1- p)
# Out:
# ======== 0 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
# ======== 1 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
# ======== 2 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
# ======== original ========
#               動画時間_correct    経過日数  プレミア公開   視聴回数    コメント  高評価件数  低評価件数
# 動画時間_correct        1.0000 -0.4725  0.6778 0.3289  0.4521 0.4101 0.1251
# 経過日数               -0.4725  1.0000 -0.6418 0.1271 -0.0774 0.0095 0.2587
# プレミア公開              0.6778 -0.6418  1.0000 0.2140  0.3776 0.3293 0.1649
# 視聴回数                0.3289  0.1271  0.2140 1.0000  0.8486 0.9104 0.8311
# コメント                0.4521 -0.0774  0.3776 0.8486  1.0000 0.8322 0.6137
# 高評価件数               0.4101  0.0095  0.3293 0.9104  0.8322 1.0000 0.6606
# 低評価件数               0.1251  0.2587  0.1649 0.8311  0.6137 0.6606 1.0000
# ======== estimated ========
#               動画時間_correct    経過日数  プレミア公開   視聴回数    コメント  高評価件数  低評価件数
# 動画時間_correct        1.0000 -0.4539  0.6778 0.3289  0.4521 0.4101 0.1251
# 経過日数               -0.4539  1.0000 -0.6418 0.1271 -0.0710 0.0095 0.2587
# プレミア公開              0.6778 -0.6418  1.0000 0.2140  0.3776 0.3293 0.1649
# 視聴回数                0.3289  0.1271  0.2140 1.0000  0.8486 0.9104 0.8311
# コメント                0.4521 -0.0710  0.3776 0.8486  1.0000 0.8270 0.6137
# 高評価件数               0.4101  0.0095  0.3293 0.9104  0.8270 1.0000 0.6606
# 低評価件数               0.1251  0.2587  0.1649 0.8311  0.6137 0.6606 1.0000
# ======== test rel to original ========
# dev: 0.02414442963565122
# p: 0.9990093946581381
# ======== test rel to prev ========
# dev: 0.012685456867682632
# p: 0.9103241111107416

# %%
print('inverse of correlation')
pd.DataFrame(inverse_cor(estimated_cors[-1]), index=df_cor.columns, columns=df_cor.columns)
# Out:
# inverse of correlation
#               動画時間_correct    経過日数  プレミア公開    視聴回数    コメント   高評価件数   低評価件数
# 動画時間_correct        1.0000  0.0000 -0.5152 -0.2325 -0.0257  0.0749  0.3104
# 経過日数               -0.0000  1.0000  0.5850  0.1352  0.0000 -0.1352 -0.3474
# プレミア公開             -0.5152  0.5850  1.0000  0.4326 -0.2184 -0.3223 -0.4902
# 視聴回数               -0.2325  0.1352  0.4326  1.0000 -0.4962 -0.7442 -0.7677
# コメント               -0.0257  0.0000 -0.2184 -0.4962  1.0000 -0.0000  0.2558
# 高評価件数               0.0749 -0.1352 -0.3223 -0.7442 -0.0000  1.0000  0.4333
# 低評価件数               0.3104 -0.3474 -0.4902 -0.7677  0.2558  0.4333  1.0000

# %%
cond_ind_pairs = [(1, 4), (4, 5), (0, 1), (0, 4)]
# estimated_cors = [df_cor.values]

estimated_cors.append(estimate(estimated_cors[-1], cond_ind_pairs))

print('========', 'original', '========')
df_original = pd.DataFrame(estimated_cors[0], index=df_cor.columns, columns=df_cor.columns)
display(df_original)

print('========', 'estimated', '========')
df_estimated = pd.DataFrame(estimated_cors[-1], index=df_cor.columns, columns=df_cor.columns)
display(df_estimated)


print('========', 'test rel to original', '========')
dev, p = deviance_and_p(estimated_cors[0], estimated_cors[-1], df=len(cond_ind_pairs))
print('dev:', dev)
print('p:', 1 - p)

print('========', 'test rel to prev', '========')
dev, p = deviance_and_p(estimated_cors[-2], estimated_cors[-1], df=1)
print('dev:', dev)
print('p:', 1 - p)
# Out:
# ======== 0 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
# ======== 1 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
# ======== 2 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
# ======== original ========
#               動画時間_correct    経過日数  プレミア公開   視聴回数    コメント  高評価件数  低評価件数
# 動画時間_correct        1.0000 -0.4725  0.6778 0.3289  0.4521 0.4101 0.1251
# 経過日数               -0.4725  1.0000 -0.6418 0.1271 -0.0774 0.0095 0.2587
# プレミア公開              0.6778 -0.6418  1.0000 0.2140  0.3776 0.3293 0.1649
# 視聴回数                0.3289  0.1271  0.2140 1.0000  0.8486 0.9104 0.8311
# コメント                0.4521 -0.0774  0.3776 0.8486  1.0000 0.8322 0.6137
# 高評価件数               0.4101  0.0095  0.3293 0.9104  0.8322 1.0000 0.6606
# 低評価件数               0.1251  0.2587  0.1649 0.8311  0.6137 0.6606 1.0000
# ======== estimated ========
#               動画時間_correct    経過日数  プレミア公開   視聴回数    コメント  高評価件数  低評価件数
# 動画時間_correct        1.0000 -0.4539  0.6778 0.3289  0.4442 0.4101 0.1251
# 経過日数               -0.4539  1.0000 -0.6418 0.1271 -0.0709 0.0095 0.2587
# プレミア公開              0.6778 -0.6418  1.0000 0.2140  0.3776 0.3293 0.1649
# 視聴回数                0.3289  0.1271  0.2140 1.0000  0.8486 0.9104 0.8311
# コメント                0.4442 -0.0709  0.3776 0.8486  1.0000 0.8273 0.6137
# 高評価件数               0.4101  0.0095  0.3293 0.9104  0.8273 1.0000 0.6606
# 低評価件数               0.1251  0.2587  0.1649 0.8311  0.6137 0.6606 1.0000
# ======== test rel to original ========
# dev: 0.028794959386753582
# p: 0.99989734574427
# ======== test rel to prev ========
# dev: 0.004650529751102361
# p: 0.9456305721485279

# %%
print('inverse of correlation')
pd.DataFrame(inverse_cor(estimated_cors[-1]), index=df_cor.columns, columns=df_cor.columns)
# Out:
# inverse of correlation
#               動画時間_correct    経過日数  プレミア公開    視聴回数    コメント   高評価件数   低評価件数
# 動画時間_correct        1.0000  0.0000 -0.5195 -0.2448 -0.0000  0.0749  0.3165
# 経過日数                0.0000  1.0000  0.5833  0.1349  0.0000 -0.1352 -0.3467
# プレミア公開             -0.5195  0.5833  1.0000  0.4378 -0.2306 -0.3214 -0.4929
# 視聴回数               -0.2448  0.1349  0.4378  1.0000 -0.4998 -0.7425 -0.7693
# コメント                0.0000  0.0000 -0.2306 -0.4998  1.0000  0.0000  0.2626
# 高評価件数               0.0749 -0.1352 -0.3214 -0.7425  0.0000  1.0000  0.4324
# 低評価件数               0.3165 -0.3467 -0.4929 -0.7693  0.2626  0.4324  1.0000

# %%
cond_ind_pairs = [(1, 4), (4, 5), (0, 1), (0, 4), (0, 5)]
# estimated_cors = [df_cor.values]

estimated_cors.append(estimate(estimated_cors[-1], cond_ind_pairs))

print('========', 'original', '========')
df_original = pd.DataFrame(estimated_cors[0], index=df_cor.columns, columns=df_cor.columns)
display(df_original)

print('========', 'estimated', '========')
df_estimated = pd.DataFrame(estimated_cors[-1], index=df_cor.columns, columns=df_cor.columns)
display(df_estimated)


print('========', 'test rel to original', '========')
dev, p = deviance_and_p(estimated_cors[0], estimated_cors[-1], df=len(cond_ind_pairs))
print('dev:', dev)
print('p:', 1 - p)

print('========', 'test rel to prev', '========')
dev, p = deviance_and_p(estimated_cors[-2], estimated_cors[-1], df=1)
print('dev:', dev)
print('p:', 1 - p)
# Out:
# ======== 0 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
# ======== 1 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
# ======== 2 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
# ======== original ========
#               動画時間_correct    経過日数  プレミア公開   視聴回数    コメント  高評価件数  低評価件数
# 動画時間_correct        1.0000 -0.4725  0.6778 0.3289  0.4521 0.4101 0.1251
# 経過日数               -0.4725  1.0000 -0.6418 0.1271 -0.0774 0.0095 0.2587
# プレミア公開              0.6778 -0.6418  1.0000 0.2140  0.3776 0.3293 0.1649
# 視聴回数                0.3289  0.1271  0.2140 1.0000  0.8486 0.9104 0.8311
# コメント                0.4521 -0.0774  0.3776 0.8486  1.0000 0.8322 0.6137
# 高評価件数               0.4101  0.0095  0.3293 0.9104  0.8322 1.0000 0.6606
# 低評価件数               0.1251  0.2587  0.1649 0.8311  0.6137 0.6606 1.0000
# ======== estimated ========
#               動画時間_correct    経過日数  プレミア公開   視聴回数    コメント  高評価件数  低評価件数
# 動画時間_correct        1.0000 -0.4493  0.6778 0.3289  0.4442 0.4277 0.1251
# 経過日数               -0.4493  1.0000 -0.6418 0.1271 -0.0709 0.0095 0.2587
# プレミア公開              0.6778 -0.6418  1.0000 0.2140  0.3776 0.3293 0.1649
# 視聴回数                0.3289  0.1271  0.2140 1.0000  0.8486 0.9104 0.8311
# コメント                0.4442 -0.0709  0.3776 0.8486  1.0000 0.8273 0.6137
# 高評価件数               0.4277  0.0095  0.3293 0.9104  0.8273 1.0000 0.6606
# 低評価件数               0.1251  0.2587  0.1649 0.8311  0.6137 0.6606 1.0000
# ======== test rel to original ========
# dev: 0.06888357116865063
# p: 0.9999353653437913
# ======== test rel to prev ========
# dev: 0.04008861178189704
# p: 0.8413074258540107

# %%
print('inverse of correlation')
pd.DataFrame(inverse_cor(estimated_cors[-1]), index=df_cor.columns, columns=df_cor.columns)
# Out:
# inverse of correlation
#               動画時間_correct    経過日数  プレミア公開    視聴回数    コメント   高評価件数   低評価件数
# 動画時間_correct        1.0000  0.0000 -0.5069 -0.1924 -0.0000 -0.0000  0.2904
# 経過日数                0.0000  1.0000  0.5885  0.1365  0.0000 -0.1355 -0.3497
# プレミア公開             -0.5069  0.5885  1.0000  0.4147 -0.2327 -0.2858 -0.4815
# 視聴回数               -0.1924  0.1365  0.4147  1.0000 -0.5058 -0.7350 -0.7622
# コメント                0.0000  0.0000 -0.2327 -0.5058  1.0000  0.0000  0.2649
# 高評価件数               0.0000 -0.1355 -0.2858 -0.7350  0.0000  1.0000  0.4135
# 低評価件数               0.2904 -0.3497 -0.4815 -0.7622  0.2649  0.4135  1.0000

# %%
cond_ind_pairs = [(1, 4), (4, 5), (0, 1), (0, 4), (0, 5), (1, 5)]
# estimated_cors = [df_cor.values]

estimated_cors.append(estimate(estimated_cors[-1], cond_ind_pairs))

print('========', 'original', '========')
df_original = pd.DataFrame(estimated_cors[0], index=df_cor.columns, columns=df_cor.columns)
display(df_original)

print('========', 'estimated', '========')
df_estimated = pd.DataFrame(estimated_cors[-1], index=df_cor.columns, columns=df_cor.columns)
display(df_estimated)


print('========', 'test rel to original', '========')
dev, p = deviance_and_p(estimated_cors[0], estimated_cors[-1], df=len(cond_ind_pairs))
print('dev:', dev)
print('p:', 1 - p)

print('========', 'test rel to prev', '========')
dev, p = deviance_and_p(estimated_cors[-2], estimated_cors[-1], df=1)
print('dev:', dev)
print('p:', 1 - p)
# Out:
# ======== 0 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
# ======== 1 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
# ======== original ========
#               動画時間_correct    経過日数  プレミア公開   視聴回数    コメント  高評価件数  低評価件数
# 動画時間_correct        1.0000 -0.4725  0.6778 0.3289  0.4521 0.4101 0.1251
# 経過日数               -0.4725  1.0000 -0.6418 0.1271 -0.0774 0.0095 0.2587
# プレミア公開              0.6778 -0.6418  1.0000 0.2140  0.3776 0.3293 0.1649
# 視聴回数                0.3289  0.1271  0.2140 1.0000  0.8486 0.9104 0.8311
# コメント                0.4521 -0.0774  0.3776 0.8486  1.0000 0.8322 0.6137
# 高評価件数               0.4101  0.0095  0.3293 0.9104  0.8322 1.0000 0.6606
# 低評価件数               0.1251  0.2587  0.1649 0.8311  0.6137 0.6606 1.0000
# ======== estimated ========
#               動画時間_correct    経過日数  プレミア公開   視聴回数    コメント   高評価件数  低評価件数
# 動画時間_correct        1.0000 -0.4493  0.6778 0.3289  0.4442  0.4277 0.1251
# 経過日数               -0.4493  1.0000 -0.6418 0.1271 -0.0709 -0.0224 0.2587
# プレミア公開              0.6778 -0.6418  1.0000 0.2140  0.3776  0.3293 0.1649
# 視聴回数                0.3289  0.1271  0.2140 1.0000  0.8486  0.9104 0.8311
# コメント                0.4442 -0.0709  0.3776 0.8486  1.0000  0.8273 0.6137
# 高評価件数               0.4277 -0.0224  0.3293 0.9104  0.8273  1.0000 0.6606
# 低評価件数               0.1251  0.2587  0.1649 0.8311  0.6137  0.6606 1.0000
# ======== test rel to original ========
# dev: 0.19868914307552377
# p: 0.9998482937813923
# ======== test rel to prev ========
# dev: 0.12980557190687314
# p: 0.7186337138109788

# %%
print('inverse of correlation')
pd.DataFrame(inverse_cor(estimated_cors[-1]), index=df_cor.columns, columns=df_cor.columns)
# Out:
# inverse of correlation
#               動画時間_correct    経過日数  プレミア公開    視聴回数    コメント   高評価件数   低評価件数
# 動画時間_correct        1.0000 -0.0000 -0.5169 -0.1940  0.0000  0.0000  0.2955
# 経過日数               -0.0000  1.0000  0.5659  0.0376 -0.0000 -0.0000 -0.3017
# プレミア公開             -0.5169  0.5659  1.0000  0.3652 -0.2373 -0.2120 -0.4568
# 視聴回数               -0.1940  0.0376  0.3652  1.0000 -0.5103 -0.7295 -0.7448
# コメント               -0.0000 -0.0000 -0.2373 -0.5103  1.0000 -0.0000  0.2696
# 高評価件数               0.0000  0.0000 -0.2120 -0.7295 -0.0000  1.0000  0.3760
# 低評価件数               0.2955 -0.3017 -0.4568 -0.7448  0.2696  0.3760  1.0000

# %%
cond_ind_pairs = [(1, 4), (4, 5), (0, 1), (0, 4), (0, 5), (1, 5), (1, 3)]
# estimated_cors = [df_cor.values]

estimated_cors.append(estimate(estimated_cors[-1], cond_ind_pairs))

print('========', 'original', '========')
df_original = pd.DataFrame(estimated_cors[0], index=df_cor.columns, columns=df_cor.columns)
display(df_original)

print('========', 'estimated', '========')
df_estimated = pd.DataFrame(estimated_cors[-1], index=df_cor.columns, columns=df_cor.columns)
display(df_estimated)


print('========', 'test rel to original', '========')
dev, p = deviance_and_p(estimated_cors[0], estimated_cors[-1], df=len(cond_ind_pairs))
print('dev:', dev)
print('p:', 1 - p)

print('========', 'test rel to prev', '========')
dev, p = deviance_and_p(estimated_cors[-2], estimated_cors[-1], df=1)
print('dev:', dev)
print('p:', 1 - p)
# Out:
# ======== 0 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
# ======== 1 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
# ======== 2 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
# ======== 3 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
# ======== 4 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
# ======== 5 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
# ======== 6 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
# ======== 7 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
# ======== 8 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
# ======== 9 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
# ======== 10 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
# ======== 11 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
# ======== 12 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
# ======== 13 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
# ======== 14 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
# ======== 15 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
# ======== 16 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
# ======== 17 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
# ======== 18 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
# ======== 19 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
# ======== 20 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
# ======== 21 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
# ======== 22 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
# ======== 23 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
# ======== 24 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
# ======== original ========
#               動画時間_correct    経過日数  プレミア公開   視聴回数    コメント  高評価件数  低評価件数
# 動画時間_correct        1.0000 -0.4725  0.6778 0.3289  0.4521 0.4101 0.1251
# 経過日数               -0.4725  1.0000 -0.6418 0.1271 -0.0774 0.0095 0.2587
# プレミア公開              0.6778 -0.6418  1.0000 0.2140  0.3776 0.3293 0.1649
# 視聴回数                0.3289  0.1271  0.2140 1.0000  0.8486 0.9104 0.8311
# コメント                0.4521 -0.0774  0.3776 0.8486  1.0000 0.8322 0.6137
# 高評価件数               0.4101  0.0095  0.3293 0.9104  0.8322 1.0000 0.6606
# 低評価件数               0.1251  0.2587  0.1649 0.8311  0.6137 0.6606 1.0000
# ======== estimated ========
#               動画時間_correct    経過日数  プレミア公開   視聴回数    コメント  高評価件数  低評価件数
# 動画時間_correct        1.0000 -0.4303  0.6778 0.3289  0.4442 0.4277 0.1251
# 経過日数               -0.4303  1.0000 -0.6418 0.1605 -0.0361 0.0154 0.2587
# プレミア公開              0.6778 -0.6418  1.0000 0.2140  0.3776 0.3293 0.1649
# 視聴回数                0.3289  0.1605  0.2140 1.0000  0.8486 0.9104 0.8311
# コメント                0.4442 -0.0361  0.3776 0.8486  1.0000 0.8273 0.6137
# 高評価件数               0.4277  0.0154  0.3293 0.9104  0.8273 1.0000 0.6606
# 低評価件数               0.1251  0.2587  0.1649 0.8311  0.6137 0.6606 1.0000
# ======== test rel to original ========
# dev: 0.25715194890346105
# p: 0.999940694115257
# ======== test rel to prev ========
# dev: 0.05846280582793728
# p: 0.8089422441550159

# %%
print('inverse of correlation')
pd.DataFrame(inverse_cor(estimated_cors[-1]), index=df_cor.columns, columns=df_cor.columns)
# Out:
# inverse of correlation
#               動画時間_correct    経過日数  プレミア公開    視聴回数    コメント   高評価件数   低評価件数
# 動画時間_correct        1.0000  0.0001 -0.5155 -0.1942  0.0000  0.0000  0.3004
# 経過日数                0.0001  1.0000  0.5689 -0.0000  0.0002  0.0003 -0.2461
# プレミア公開             -0.5155  0.5689  1.0000  0.3433 -0.2365 -0.2113 -0.4301
# 視聴回数               -0.1942  0.0000  0.3433  1.0000 -0.5106 -0.7300 -0.7462
# コメント                0.0000  0.0002 -0.2365 -0.5106  1.0000  0.0000  0.2740
# 高評価件数               0.0000  0.0003 -0.2113 -0.7300  0.0000  1.0000  0.3822
# 低評価件数               0.3004 -0.2461 -0.4301 -0.7462  0.2740  0.3822  1.0000

# %%
cond_ind_pairs = [(1, 4), (4, 5), (0, 1), (0, 4), (0, 5), (1, 5), (1, 3), (0, 3)]
# estimated_cors = [df_cor.values]

estimated_cors.append(estimate(estimated_cors[-1], cond_ind_pairs))

print('========', 'original', '========')
df_original = pd.DataFrame(estimated_cors[0], index=df_cor.columns, columns=df_cor.columns)
display(df_original)

print('========', 'estimated', '========')
df_estimated = pd.DataFrame(estimated_cors[-1], index=df_cor.columns, columns=df_cor.columns)
display(df_estimated)


print('========', 'test rel to original', '========')
dev, p = deviance_and_p(estimated_cors[0], estimated_cors[-1], df=len(cond_ind_pairs))
print('dev:', dev)
print('p:', 1 - p)

print('========', 'test rel to prev', '========')
dev, p = deviance_and_p(estimated_cors[-2], estimated_cors[-1], df=1)
print('dev:', dev)
print('p:', 1 - p)
# Out:
# ======== 0 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
# ======== 1 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
# ======== 2 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
# ======== 3 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
# ======== 4 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
# ======== 5 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
# ======== 6 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
# ======== 7 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
# ======== 8 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
# ======== 9 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
# ======== 10 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
# ======== 11 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
# ======== 12 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
# ======== 13 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
# ======== 14 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
# ======== 15 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
# ======== 16 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
# ======== 17 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
# ======== 18 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
# ======== 19 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
# ======== 20 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
# ======== 21 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
# ======== 22 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
# ======== 23 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
# ======== 24 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
# ======== 25 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
# ======== 26 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
# ======== 27 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
# ======== 28 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
# ======== 29 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
# ======== 30 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
# ======== 31 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
# ======== 32 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
# ======== original ========
#               動画時間_correct    経過日数  プレミア公開   視聴回数    コメント  高評価件数  低評価件数
# 動画時間_correct        1.0000 -0.4725  0.6778 0.3289  0.4521 0.4101 0.1251
# 経過日数               -0.4725  1.0000 -0.6418 0.1271 -0.0774 0.0095 0.2587
# プレミア公開              0.6778 -0.6418  1.0000 0.2140  0.3776 0.3293 0.1649
# 視聴回数                0.3289  0.1271  0.2140 1.0000  0.8486 0.9104 0.8311
# コメント                0.4521 -0.0774  0.3776 0.8486  1.0000 0.8322 0.6137
# 高評価件数               0.4101  0.0095  0.3293 0.9104  0.8322 1.0000 0.6606
# 低評価件数               0.1251  0.2587  0.1649 0.8311  0.6137 0.6606 1.0000
# ======== estimated ========
#               動画時間_correct    経過日数  プレミア公開   視聴回数    コメント  高評価件数  低評価件数
# 動画時間_correct        1.0000 -0.4300  0.6778 0.1562  0.2638 0.2319 0.1251
# 経過日数               -0.4300  1.0000 -0.6418 0.1609 -0.0357 0.0159 0.2587
# プレミア公開              0.6778 -0.6418  1.0000 0.2140  0.3776 0.3293 0.1649
# 視聴回数                0.1562  0.1609  0.2140 1.0000  0.8486 0.9104 0.8311
# コメント                0.2638 -0.0357  0.3776 0.8486  1.0000 0.8273 0.6137
# 高評価件数               0.2319  0.0159  0.3293 0.9104  0.8273 1.0000 0.6606
# 低評価件数               0.1251  0.2587  0.1649 0.8311  0.6137 0.6606 1.0000
# ======== test rel to original ========
# dev: 1.669469335360155
# p: 0.9895239563160149
# ======== test rel to prev ========
# dev: 1.412317386456694
# p: 0.23467207457078743

# %%
print('inverse of correlation')
pd.DataFrame(inverse_cor(estimated_cors[-1]), index=df_cor.columns, columns=df_cor.columns)
# Out:
# inverse of correlation
#               動画時間_correct    経過日数  プレミア公開    視聴回数    コメント   高評価件数   低評価件数
# 動画時間_correct        1.0000  0.0000 -0.5034 -0.0000 -0.0002 -0.0003 -0.0082
# 経過日数                0.0000  1.0000  0.5738  0.0000  0.0000  0.0000 -0.2576
# プレミア公開             -0.5034  0.5738  1.0000  0.2499 -0.2385 -0.2131 -0.2866
# 視聴回数               -0.0000  0.0000  0.2499  1.0000 -0.5205 -0.7442 -0.7352
# コメント               -0.0002  0.0000 -0.2385 -0.5205  1.0000 -0.0000  0.2874
# 高評価件数              -0.0003  0.0000 -0.2131 -0.7442 -0.0000  1.0000  0.4008
# 低評価件数              -0.0082 -0.2576 -0.2866 -0.7352  0.2874  0.4008  1.0000

# %%
cond_ind_pairs = [(1, 4), (4, 5), (0, 1), (0, 4), (0, 5), (1, 5), (1, 3), (0, 3), (2, 5)]
# estimated_cors = [df_cor.values]

estimated_cors.append(estimate(estimated_cors[-1], cond_ind_pairs))

print('========', 'original', '========')
df_original = pd.DataFrame(estimated_cors[0], index=df_cor.columns, columns=df_cor.columns)
display(df_original)

print('========', 'estimated', '========')
df_estimated = pd.DataFrame(estimated_cors[-1], index=df_cor.columns, columns=df_cor.columns)
display(df_estimated)


print('========', 'test rel to original', '========')
dev, p = deviance_and_p(estimated_cors[0], estimated_cors[-1], df=len(cond_ind_pairs))
print('dev:', dev)
print('p:', 1 - p)

print('========', 'test rel to prev', '========')
dev, p = deviance_and_p(estimated_cors[-2], estimated_cors[-1], df=1)
print('dev:', dev)
print('p:', 1 - p)
# Out:
# ======== 0 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
# ======== 1 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
# ======== 2 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
# ======== 3 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
# ======== 4 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
# ======== 5 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
# ======== 6 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
# ======== 7 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
# ======== 8 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
# ======== 9 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
# ======== 10 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
# ======== 11 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
# ======== 12 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
# ======== 13 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
# ======== 14 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
# ======== 15 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
# ======== 16 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
# ======== original ========
#               動画時間_correct    経過日数  プレミア公開   視聴回数    コメント  高評価件数  低評価件数
# 動画時間_correct        1.0000 -0.4725  0.6778 0.3289  0.4521 0.4101 0.1251
# 経過日数               -0.4725  1.0000 -0.6418 0.1271 -0.0774 0.0095 0.2587
# プレミア公開              0.6778 -0.6418  1.0000 0.2140  0.3776 0.3293 0.1649
# 視聴回数                0.3289  0.1271  0.2140 1.0000  0.8486 0.9104 0.8311
# コメント                0.4521 -0.0774  0.3776 0.8486  1.0000 0.8322 0.6137
# 高評価件数               0.4101  0.0095  0.3293 0.9104  0.8322 1.0000 0.6606
# 低評価件数               0.1251  0.2587  0.1649 0.8311  0.6137 0.6606 1.0000
# ======== estimated ========
#               動画時間_correct    経過日数  プレミア公開   視聴回数    コメント  高評価件数  低評価件数
# 動画時間_correct        1.0000 -0.4300  0.6778 0.1560  0.2635 0.1436 0.1251
# 経過日数               -0.4300  1.0000 -0.6418 0.1608 -0.0357 0.1073 0.2587
# プレミア公開              0.6778 -0.6418  1.0000 0.2140  0.3776 0.1991 0.1649
# 視聴回数                0.1560  0.1608  0.2140 1.0000  0.8486 0.9104 0.8311
# コメント                0.2635 -0.0357  0.3776 0.8486  1.0000 0.8011 0.6137
# 高評価件数               0.1436  0.1073  0.1991 0.9104  0.8011 1.0000 0.6606
# 低評価件数               0.1251  0.2587  0.1649 0.8311  0.6137 0.6606 1.0000
# ======== test rel to original ========
# dev: 2.613425097762094
# p: 0.977675858634343
# ======== test rel to prev ========
# dev: 0.9439557624019388
# p: 0.33126259288192206

# %%
print('inverse of correlation')
pd.DataFrame(inverse_cor(estimated_cors[-1]), index=df_cor.columns, columns=df_cor.columns)
# Out:
# inverse of correlation
#               動画時間_correct    経過日数  プレミア公開    視聴回数    コメント   高評価件数   低評価件数
# 動画時間_correct        1.0000  0.0000 -0.5154  0.0001 -0.0000 -0.0002 -0.0087
# 経過日数                0.0000  1.0000  0.5873 -0.0002  0.0000  0.0003 -0.2596
# プレミア公開             -0.5154  0.5873  1.0000  0.0954 -0.2442 -0.0000 -0.2073
# 視聴回数                0.0001 -0.0002  0.0954  1.0000 -0.5313 -0.7314 -0.7306
# コメント               -0.0000  0.0000 -0.2442 -0.5313  1.0000 -0.0001  0.2895
# 高評価件数              -0.0002  0.0003  0.0000 -0.7314 -0.0001  1.0000  0.3845
# 低評価件数              -0.0087 -0.2596 -0.2073 -0.7306  0.2895  0.3845  1.0000

# %%
cond_ind_pairs = [(1, 4), (4, 5), (0, 1), (0, 4), (0, 5), (1, 5), (1, 3), (0, 3), (2, 5), (2, 3)]
# estimated_cors = [df_cor.values]

estimated_cors.append(estimate(estimated_cors[-1], cond_ind_pairs))

print('========', 'original', '========')
df_original = pd.DataFrame(estimated_cors[0], index=df_cor.columns, columns=df_cor.columns)
display(df_original)

print('========', 'estimated', '========')
df_estimated = pd.DataFrame(estimated_cors[-1], index=df_cor.columns, columns=df_cor.columns)
display(df_estimated)


print('========', 'test rel to original', '========')
dev, p = deviance_and_p(estimated_cors[0], estimated_cors[-1], df=len(cond_ind_pairs))
print('dev:', dev)
print('p:', 1 - p)

print('========', 'test rel to prev', '========')
dev, p = deviance_and_p(estimated_cors[-2], estimated_cors[-1], df=1)
print('dev:', dev)
print('p:', 1 - p)
# Out:
# ======== 0 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
# ======== 1 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
# ======== 2 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
# ======== 3 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
# ======== 4 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
# ======== 5 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
# ======== 6 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
# ======== 7 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
# ======== 8 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
# ======== 9 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
# ======== 10 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
# ======== 11 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
# ======== 12 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
# ======== 13 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
# ======== 14 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
# ======== 15 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
# ======== 16 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
# ======== 17 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
# ======== 18 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
# ======== 19 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
# ======== 20 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
# ======== 21 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
# ======== 22 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
# ======== 23 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
# ======== 24 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
# ======== 25 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
# ======== 26 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
# ======== 27 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
# ======== 28 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
# ======== 29 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
# ======== 30 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
# ======== 31 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
# ======== 32 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
# ======== 33 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
# ======== 34 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
# ======== 35 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
# ======== 36 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
# ======== 37 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
# ======== 38 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
# ======== 39 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
# ======== 40 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
# ======== 41 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
# ======== 42 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
# ======== 43 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
# ======== 44 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
# ======== 45 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
# ======== 46 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
# ======== 47 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
# ======== original ========
#               動画時間_correct    経過日数  プレミア公開   視聴回数    コメント  高評価件数  低評価件数
# 動画時間_correct        1.0000 -0.4725  0.6778 0.3289  0.4521 0.4101 0.1251
# 経過日数               -0.4725  1.0000 -0.6418 0.1271 -0.0774 0.0095 0.2587
# プレミア公開              0.6778 -0.6418  1.0000 0.2140  0.3776 0.3293 0.1649
# 視聴回数                0.3289  0.1271  0.2140 1.0000  0.8486 0.9104 0.8311
# コメント                0.4521 -0.0774  0.3776 0.8486  1.0000 0.8322 0.6137
# 高評価件数               0.4101  0.0095  0.3293 0.9104  0.8322 1.0000 0.6606
# 低評価件数               0.1251  0.2587  0.1649 0.8311  0.6137 0.6606 1.0000
# ======== estimated ========
#               動画時間_correct    経過日数  プレミア公開   視聴回数    コメント  高評価件数  低評価件数
# 動画時間_correct        1.0000 -0.4300  0.6778 0.2049  0.2632 0.2002 0.1251
# 経過日数               -0.4300  1.0000 -0.6418 0.1099 -0.0354 0.0484 0.2587
# プレミア公開              0.6778 -0.6418  1.0000 0.2868  0.3776 0.2836 0.1649
# 視聴回数                0.2049  0.1099  0.2868 1.0000  0.8486 0.9104 0.8311
# コメント                0.2632 -0.0354  0.3776 0.8486  1.0000 0.8010 0.6137
# 高評価件数               0.2002  0.0484  0.2836 0.9104  0.8010 1.0000 0.6606
# 低評価件数               0.1251  0.2587  0.1649 0.8311  0.6137 0.6606 1.0000
# ======== test rel to original ========
# dev: 2.9736990087956894
# p: 0.9820362468735725
# ======== test rel to prev ========
# dev: 0.3602739110335955
# p: 0.548354151680343

# %%
print('inverse of correlation')
pd.DataFrame(inverse_cor(estimated_cors[-1]), index=df_cor.columns, columns=df_cor.columns)
# Out:
# inverse of correlation
#               動画時間_correct    経過日数  プレミア公開    視聴回数    コメント   高評価件数   低評価件数
# 動画時間_correct        1.0000  0.0000 -0.5205 -0.0000  0.0001  0.0003 -0.0089
# 経過日数                0.0000  1.0000  0.5932  0.0000 -0.0001 -0.0004 -0.2601
# プレミア公開             -0.5205  0.5932  1.0000  0.0000 -0.1448  0.0002 -0.1165
# 視聴回数               -0.0000  0.0000  0.0000  1.0000 -0.5041 -0.7402 -0.7270
# コメント                0.0001 -0.0001 -0.1448 -0.5041  1.0000  0.0000  0.2548
# 高評価件数               0.0003 -0.0004  0.0002 -0.7402  0.0000  1.0000  0.3860
# 低評価件数              -0.0089 -0.2601 -0.1165 -0.7270  0.2548  0.3860  1.0000

# %%
cond_ind_pairs = [(1, 4), (4, 5), (0, 1), (0, 4), (0, 5), (1, 5), (1, 3), (0, 3), (2, 5), (2, 3), (2, 6)]
# estimated_cors = [df_cor.values]

estimated_cors.append(estimate(estimated_cors[-1], cond_ind_pairs))

print('========', 'original', '========')
df_original = pd.DataFrame(estimated_cors[0], index=df_cor.columns, columns=df_cor.columns)
display(df_original)

print('========', 'estimated', '========')
df_estimated = pd.DataFrame(estimated_cors[-1], index=df_cor.columns, columns=df_cor.columns)
display(df_estimated)


print('========', 'test rel to original', '========')
dev, p = deviance_and_p(estimated_cors[0], estimated_cors[-1], df=len(cond_ind_pairs))
print('dev:', dev)
print('p:', 1 - p)

print('========', 'test rel to prev', '========')
dev, p = deviance_and_p(estimated_cors[-2], estimated_cors[-1], df=1)
print('dev:', dev)
print('p:', 1 - p)
# Out:
# ======== 0 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
# ======== 1 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
# ======== 2 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
# ======== 3 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
# ======== 4 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
# ======== 5 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
# ======== 6 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
# ======== 7 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
# ======== 8 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
# ======== 9 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
# ======== 10 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
# ======== 11 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
# ======== 12 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
# ======== 13 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
# ======== 14 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
# ======== 15 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
# ======== 16 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
# ======== 17 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
# ======== 18 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
# ======== 19 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
# ======== 20 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
# ======== 21 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
# ======== 22 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
# ======== 23 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
# ======== 24 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
# ======== 25 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
# ======== 26 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
# ======== 27 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
# ======== 28 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
# ======== 29 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
# ======== 30 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
# ======== 31 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
# ======== 32 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
# ======== 33 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
# ======== 34 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
# ======== 35 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
# ======== 36 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
# ======== 37 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
# ======== original ========
#               動画時間_correct    経過日数  プレミア公開   視聴回数    コメント  高評価件数  低評価件数
# 動画時間_correct        1.0000 -0.4725  0.6778 0.3289  0.4521 0.4101 0.1251
# 経過日数               -0.4725  1.0000 -0.6418 0.1271 -0.0774 0.0095 0.2587
# プレミア公開              0.6778 -0.6418  1.0000 0.2140  0.3776 0.3293 0.1649
# 視聴回数                0.3289  0.1271  0.2140 1.0000  0.8486 0.9104 0.8311
# コメント                0.4521 -0.0774  0.3776 0.8486  1.0000 0.8322 0.6137
# 高評価件数               0.4101  0.0095  0.3293 0.9104  0.8322 1.0000 0.6606
# 低評価件数               0.1251  0.2587  0.1649 0.8311  0.6137 0.6606 1.0000
# ======== estimated ========
#               動画時間_correct    経過日数  プレミア公開   視聴回数    コメント  高評価件数  低評価件数
# 動画時間_correct        1.0000 -0.4116  0.6778 0.2261  0.3013 0.2257 0.1251
# 経過日数               -0.4116  1.0000 -0.6418 0.0944 -0.0629 0.0296 0.2587
# プレミア公開              0.6778 -0.6418  1.0000 0.2410  0.3776 0.2597 0.0716
# 視聴回数                0.2261  0.0944  0.2410 1.0000  0.8486 0.9104 0.8311
# コメント                0.3013 -0.0629  0.3776 0.8486  1.0000 0.8011 0.6137
# 高評価件数               0.2257  0.0296  0.2597 0.9104  0.8011 1.0000 0.6606
# 低評価件数               0.1251  0.2587  0.0716 0.8311  0.6137 0.6606 1.0000
# ======== test rel to original ========
# dev: 3.255470078277238
# p: 0.9869005372573536
# ======== test rel to prev ========
# dev: 0.2817710694815485
# p: 0.5955427378666904

# %%
print('inverse of correlation')
pd.DataFrame(inverse_cor(estimated_cors[-1]), index=df_cor.columns, columns=df_cor.columns)
# Out:
# inverse of correlation
#               動画時間_correct    経過日数  プレミア公開    視聴回数    コメント   高評価件数   低評価件数
# 動画時間_correct        1.0000 -0.0000 -0.5343  0.0000 -0.0001 -0.0003 -0.0491
# 経過日数               -0.0000  1.0000  0.5483 -0.0000  0.0001  0.0003 -0.2045
# プレミア公開             -0.5343  0.5483  1.0000  0.0000 -0.1831 -0.0002  0.0000
# 視聴回数                0.0000 -0.0000  0.0000  1.0000 -0.4969 -0.7401 -0.7303
# コメント               -0.0001  0.0001 -0.1831 -0.4969  1.0000 -0.0000  0.2268
# 高評価件数              -0.0003  0.0003 -0.0002 -0.7401 -0.0000  1.0000  0.3874
# 低評価件数              -0.0491 -0.2045 -0.0000 -0.7303  0.2268  0.3874  1.0000

# %%
cond_ind_pairs = [(1, 4), (4, 5), (0, 1), (0, 4), (0, 5), (1, 5), (1, 3), (0, 3), (2, 5), (2, 3), (2, 6), (0, 6)]
# estimated_cors = [df_cor.values]

estimated_cors.append(estimate(estimated_cors[-1], cond_ind_pairs))

print('========', 'original', '========')
df_original = pd.DataFrame(estimated_cors[0], index=df_cor.columns, columns=df_cor.columns)
display(df_original)

print('========', 'estimated', '========')
df_estimated = pd.DataFrame(estimated_cors[-1], index=df_cor.columns, columns=df_cor.columns)
display(df_estimated)


print('========', 'test rel to original', '========')
dev, p = deviance_and_p(estimated_cors[0], estimated_cors[-1], df=len(cond_ind_pairs))
print('dev:', dev)
print('p:', 1 - p)

print('========', 'test rel to prev', '========')
dev, p = deviance_and_p(estimated_cors[-2], estimated_cors[-1], df=1)
print('dev:', dev)
print('p:', 1 - p)
# Out:
# ======== 0 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
# ======== 1 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
# ======== 2 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
# ======== 3 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
# ======== 4 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
# ======== 5 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
# ======== 6 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
# ======== 7 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
# ======== 8 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
# ======== 9 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
# ======== 10 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
# ======== 11 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
# ======== 12 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
# ======== 13 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
# ======== 14 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
# ======== 15 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
# ======== 16 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
# ======== 17 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
# ======== 18 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
# ======== 19 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
# ======== 20 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
# ======== 21 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
# ======== 22 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
# ======== 23 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
# ======== 24 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
# ======== 25 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
# ======== 26 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
# ======== 27 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
# ======== 28 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
# ======== 29 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
# ======== 30 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
# ======== 31 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
# ======== 32 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
# ======== 33 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
# ======== 34 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
# ======== 35 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
# ======== 36 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
# ======== 37 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
# ======== 38 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
# ======== 39 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
# ======== 40 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
# ======== 41 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
# ======== 42 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
# ======== 43 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
# ======== 44 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
# ======== 45 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
# ======== 46 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
# ======== 47 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
# ======== 48 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
# ======== 49 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
# ======== 50 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
# ======== 51 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
# ======== 52 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
# ======== 53 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
# ======== 54 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
# ======== 55 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
# ======== 56 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
# ======== 57 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
# ======== 58 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
# ======== 59 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
# ======== 60 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
# ======== 61 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
# ======== 62 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
# ======== 63 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
# ======== 64 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
# ======== 65 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
# ======== 66 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
# ======== original ========
#               動画時間_correct    経過日数  プレミア公開   視聴回数    コメント  高評価件数  低評価件数
# 動画時間_correct        1.0000 -0.4725  0.6778 0.3289  0.4521 0.4101 0.1251
# 経過日数               -0.4725  1.0000 -0.6418 0.1271 -0.0774 0.0095 0.2587
# プレミア公開              0.6778 -0.6418  1.0000 0.2140  0.3776 0.3293 0.1649
# 視聴回数                0.3289  0.1271  0.2140 1.0000  0.8486 0.9104 0.8311
# コメント                0.4521 -0.0774  0.3776 0.8486  1.0000 0.8322 0.6137
# 高評価件数               0.4101  0.0095  0.3293 0.9104  0.8322 1.0000 0.6606
# 低評価件数               0.1251  0.2587  0.1649 0.8311  0.6137 0.6606 1.0000
# ======== estimated ========
#               動画時間_correct    経過日数  プレミア公開   視聴回数    コメント  高評価件数  低評価件数
# 動画時間_correct        1.0000 -0.4347  0.6778 0.1556  0.2569 0.1722 0.0316
# 経過日数               -0.4347  1.0000 -0.6418 0.0904 -0.0703 0.0252 0.2587
# プレミア公開              0.6778 -0.6418  1.0000 0.2278  0.3776 0.2523 0.0453
# 視聴回数                0.1556  0.0904  0.2278 1.0000  0.8486 0.9104 0.8311
# コメント                0.2569 -0.0703  0.3776 0.8486  1.0000 0.8011 0.6137
# 高評価件数               0.1722  0.0252  0.2523 0.9104  0.8011 1.0000 0.6606
# 低評価件数               0.0316  0.2587  0.0453 0.8311  0.6137 0.6606 1.0000
# ======== test rel to original ========
# dev: 3.3499759407471066
# p: 0.9925282016706072
# ======== test rel to prev ========
# dev: 0.0945058624698687
# p: 0.7585251848393986

# %%
print('inverse of correlation')
pd.DataFrame(inverse_cor(estimated_cors[-1]), index=df_cor.columns, columns=df_cor.columns)
# Out:
# inverse of correlation
#               動画時間_correct    経過日数  プレミア公開    視聴回数    コメント   高評価件数   低評価件数
# 動画時間_correct        1.0000 -0.0000 -0.5369 -0.0001 -0.0002 -0.0003  0.0000
# 経過日数               -0.0000  1.0000  0.5369  0.0000 -0.0000  0.0001 -0.1905
# プレミア公開             -0.5369  0.5369  1.0000  0.0000 -0.1952 -0.0001 -0.0001
# 視聴回数               -0.0001  0.0000  0.0000  1.0000 -0.4945 -0.7401 -0.7308
# コメント               -0.0002 -0.0000 -0.1952 -0.4945  1.0000 -0.0000  0.2167
# 高評価件数              -0.0003  0.0001 -0.0001 -0.7401 -0.0000  1.0000  0.3877
# 低評価件数               0.0000 -0.1905 -0.0001 -0.7308  0.2167  0.3877  1.0000

# %%
cond_ind_pairs = [(1, 4), (4, 5), (0, 1), (0, 4), (0, 5), (1, 5), (1, 3), (0, 3), (2, 5), (2, 3), (2, 6), (0, 6), (1, 6)]
# estimated_cors = [df_cor.values]

estimated_cors.append(estimate(estimated_cors[-1], cond_ind_pairs))

print('========', 'original', '========')
df_original = pd.DataFrame(estimated_cors[0], index=df_cor.columns, columns=df_cor.columns)
display(df_original)

print('========', 'estimated', '========')
df_estimated = pd.DataFrame(estimated_cors[-1], index=df_cor.columns, columns=df_cor.columns)
display(df_estimated)


print('========', 'test rel to original', '========')
dev, p = deviance_and_p(estimated_cors[0], estimated_cors[-1], df=len(cond_ind_pairs))
print('dev:', dev)
print('p:', 1 - p)

print('========', 'test rel to prev', '========')
dev, p = deviance_and_p(estimated_cors[-2], estimated_cors[-1], df=1)
print('dev:', dev)
print('p:', 1 - p)
# Out:
# ======== 0 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 1 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 2 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 3 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 4 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 5 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 6 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 7 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 8 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 9 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 10 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 11 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 12 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 13 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 14 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 15 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 16 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 17 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 18 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 19 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 20 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 21 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 22 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 23 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 24 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 25 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 26 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 27 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 28 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 29 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 30 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 31 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 32 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 33 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 34 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 35 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 36 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 37 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 38 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 39 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 40 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 41 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 42 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 43 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 44 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 45 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 46 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 47 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 48 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 49 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 50 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 51 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 52 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 53 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 54 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 55 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 56 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 57 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 58 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 59 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 60 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 61 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 62 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 63 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 64 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 65 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 66 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 67 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 68 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 69 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 70 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 71 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 72 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 73 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 74 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 75 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 76 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 77 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 78 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 79 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 80 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 81 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 82 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 83 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 84 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 85 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 86 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 87 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 88 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 89 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 90 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 91 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 92 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 93 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 94 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 95 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 96 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 97 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 98 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== 99 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
# ======== original ========
#               動画時間_correct    経過日数  プレミア公開   視聴回数    コメント  高評価件数  低評価件数
# 動画時間_correct        1.0000 -0.4725  0.6778 0.3289  0.4521 0.4101 0.1251
# 経過日数               -0.4725  1.0000 -0.6418 0.1271 -0.0774 0.0095 0.2587
# プレミア公開              0.6778 -0.6418  1.0000 0.2140  0.3776 0.3293 0.1649
# 視聴回数                0.3289  0.1271  0.2140 1.0000  0.8486 0.9104 0.8311
# コメント                0.4521 -0.0774  0.3776 0.8486  1.0000 0.8322 0.6137
# 高評価件数               0.4101  0.0095  0.3293 0.9104  0.8322 1.0000 0.6606
# 低評価件数               0.1251  0.2587  0.1649 0.8311  0.6137 0.6606 1.0000
# ======== estimated ========
#               動画時間_correct    経過日数  プレミア公開    視聴回数    コメント   高評価件数   低評価件数
# 動画時間_correct        1.0000 -0.4350  0.6778  0.2154  0.2549  0.2031  0.1554
# 経過日数               -0.4350  1.0000 -0.6418 -0.2038 -0.2413 -0.1922 -0.1471
# プレミア公開              0.6778 -0.6418  1.0000  0.3194  0.3776  0.3013  0.2306
# 視聴回数                0.2154 -0.2038  0.3194  1.0000  0.8486  0.9104  0.8311
# コメント                0.2549 -0.2413  0.3776  0.8486  1.0000  0.8010  0.6137
# 高評価件数               0.2031 -0.1922  0.3013  0.9104  0.8010  1.0000  0.6606
# 低評価件数               0.1554 -0.1471  0.2306  0.8311  0.6137  0.6606  1.0000
# ======== test rel to original ========
# dev: 4.88520824723089
# p: 0.9776338440418916
# ======== test rel to prev ========
# dev: 1.5352323064837838
# p: 0.21532886424725506

# %%
print('inverse of correlation')
pd.DataFrame(inverse_cor(estimated_cors[-1]), index=df_cor.columns, columns=df_cor.columns)
# Out:
# inverse of correlation
#               動画時間_correct    経過日数  プレミア公開    視聴回数    コメント   高評価件数   低評価件数
# 動画時間_correct        1.0000  0.0000 -0.5595  0.0002  0.0001  0.0003  0.0000
# 経過日数                0.0000  1.0000  0.5079 -0.0002 -0.0001 -0.0003 -0.0000
# プレミア公開             -0.5595  0.5079  1.0000 -0.0000 -0.1327  0.0003  0.0002
# 視聴回数                0.0002 -0.0002 -0.0000  1.0000 -0.5080 -0.7402 -0.7541
# コメント                0.0001 -0.0001 -0.1327 -0.5080  1.0000  0.0000  0.2795
# 高評価件数               0.0003 -0.0003  0.0003 -0.7402  0.0000  1.0000  0.4003
# 低評価件数               0.0000  0.0000  0.0002 -0.7541  0.2795  0.4003  1.0000

# %%
cond_ind_pairs = [(1, 4), (4, 5), (0, 1), (0, 4), (0, 5), (1, 5), (1, 3), (0, 3), (2, 5), (2, 3), (2, 6), (0, 6), (1, 6), (2, 4)]
# estimated_cors = [df_cor.values]

estimated_cors.append(estimate(estimated_cors[-1], cond_ind_pairs))

print('========', 'original', '========')
df_original = pd.DataFrame(estimated_cors[0], index=df_cor.columns, columns=df_cor.columns)
display(df_original)

print('========', 'estimated', '========')
df_estimated = pd.DataFrame(estimated_cors[-1], index=df_cor.columns, columns=df_cor.columns)
display(df_estimated)


print('========', 'test rel to original', '========')
dev, p = deviance_and_p(estimated_cors[0], estimated_cors[-1], df=len(cond_ind_pairs))
print('dev:', dev)
print('p:', 1 - p)

print('========', 'test rel to prev', '========')
dev, p = deviance_and_p(estimated_cors[-2], estimated_cors[-1], df=1)
print('dev:', dev)
print('p:', 1 - p)
# Out:
# ======== 0 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 1 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 2 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 3 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 4 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 5 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 6 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 7 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 8 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 9 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 10 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 11 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 12 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 13 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 14 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 15 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 16 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 17 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 18 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 19 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 20 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 21 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 22 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 23 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 24 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 25 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 26 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 27 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 28 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 29 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 30 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 31 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 32 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 33 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 34 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 35 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 36 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 37 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 38 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 39 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 40 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 41 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 42 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 43 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 44 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 45 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 46 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 47 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 48 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 49 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 50 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 51 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 52 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 53 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 54 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 55 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 56 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 57 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 58 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 59 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 60 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 61 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 62 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 63 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 64 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 65 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 66 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 67 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 68 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 69 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 70 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 71 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 72 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 73 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 74 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 75 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 76 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 77 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 78 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 79 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 80 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 81 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 82 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 83 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 84 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 85 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 86 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 87 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 88 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 89 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 90 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 91 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 92 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 93 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 94 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 95 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 96 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 97 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 98 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 99 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 100 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 101 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 102 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 103 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 104 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 105 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 106 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 107 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 108 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 109 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 110 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 111 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 112 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 113 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 114 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 115 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 116 -th iteration ========
#      ======== 1 4 ========
# ...
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 214 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 215 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 216 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 217 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 218 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 219 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 220 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 221 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 222 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 223 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 224 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 225 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 226 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 227 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 228 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 229 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 230 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 231 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 232 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 233 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 234 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 235 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 236 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 237 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 238 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 239 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 240 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 241 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 242 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 243 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 244 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 245 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 246 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 247 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== 248 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
# ======== original ========
#               動画時間_correct    経過日数  プレミア公開   視聴回数    コメント  高評価件数  低評価件数
# 動画時間_correct        1.0000 -0.4725  0.6778 0.3289  0.4521 0.4101 0.1251
# 経過日数               -0.4725  1.0000 -0.6418 0.1271 -0.0774 0.0095 0.2587
# プレミア公開              0.6778 -0.6418  1.0000 0.2140  0.3776 0.3293 0.1649
# 視聴回数                0.3289  0.1271  0.2140 1.0000  0.8486 0.9104 0.8311
# コメント                0.4521 -0.0774  0.3776 0.8486  1.0000 0.8322 0.6137
# 高評価件数               0.4101  0.0095  0.3293 0.9104  0.8322 1.0000 0.6606
# 低評価件数               0.1251  0.2587  0.1649 0.8311  0.6137 0.6606 1.0000
# ======== estimated ========
#               動画時間_correct    経過日数  プレミア公開    視聴回数    コメント   高評価件数   低評価件数
# 動画時間_correct        1.0000 -0.4350  0.6778  0.0057  0.0051  0.0057  0.0046
# 経過日数               -0.4350  1.0000 -0.6418 -0.0054 -0.0048 -0.0054 -0.0043
# プレミア公開              0.6778 -0.6418  1.0000  0.0065  0.0057  0.0064  0.0052
# 視聴回数                0.0057 -0.0054  0.0065  1.0000  0.8486  0.9104  0.8311
# コメント                0.0051 -0.0048  0.0057  0.8486  1.0000  0.8010  0.6137
# 高評価件数               0.0057 -0.0054  0.0064  0.9104  0.8010  1.0000  0.6606
# 低評価件数               0.0046 -0.0043  0.0052  0.8311  0.6137  0.6606  1.0000
# ======== test rel to original ========
# dev: 5.961468961601636
# p: 0.9674532932864696
# ======== test rel to prev ========
# dev: 1.0762607143707452
# p: 0.2995355682703411

# %%
print('inverse of correlation')
pd.DataFrame(inverse_cor(estimated_cors[-1]), index=df_cor.columns, columns=df_cor.columns)
# Out:
# inverse of correlation
#               動画時間_correct   経過日数  プレミア公開    視聴回数    コメント   高評価件数   低評価件数
# 動画時間_correct        1.0000 0.0000 -0.5773 -0.0002 -0.0002 -0.0003 -0.0000
# 経過日数                0.0000 1.0000  0.5241  0.0001  0.0002  0.0003  0.0000
# プレミア公開             -0.5773 0.5241  1.0000 -0.0002  0.0000 -0.0005 -0.0001
# 視聴回数               -0.0002 0.0001 -0.0002  1.0000 -0.5185 -0.7401 -0.7541
# コメント               -0.0002 0.0002  0.0000 -0.5185  1.0000  0.0000  0.2854
# 高評価件数              -0.0003 0.0003 -0.0005 -0.7401  0.0000  1.0000  0.4002
# 低評価件数              -0.0000 0.0000 -0.0001 -0.7541  0.2854  0.4002  1.0000

# %%
cond_ind_pairs = [(1, 4), (4, 5), (0, 1), (0, 4), (0, 5), (1, 5), (1, 3), (0, 3), (2, 5), (2, 3), (2, 6), (0, 6), (1, 6), (2, 4), (4, 6)]
# estimated_cors = [df_cor.values]

estimated_cors.append(estimate(estimated_cors[-1], cond_ind_pairs))

print('========', 'original', '========')
df_original = pd.DataFrame(estimated_cors[0], index=df_cor.columns, columns=df_cor.columns)
display(df_original)

print('========', 'estimated', '========')
df_estimated = pd.DataFrame(estimated_cors[-1], index=df_cor.columns, columns=df_cor.columns)
display(df_estimated)


print('========', 'test rel to original', '========')
dev, p = deviance_and_p(estimated_cors[0], estimated_cors[-1], df=len(cond_ind_pairs))
print('dev:', dev)
print('p:', 1 - p)

print('========', 'test rel to prev', '========')
dev, p = deviance_and_p(estimated_cors[-2], estimated_cors[-1], df=1)
print('dev:', dev)
print('p:', 1 - p)
# Out:
# ======== 0 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
#      ======== 4 6 ========
# ======== 1 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
#      ======== 4 6 ========
# ======== 2 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
#      ======== 4 6 ========
# ======== 3 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
#      ======== 4 6 ========
# ======== 4 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
#      ======== 4 6 ========
# ======== 5 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
#      ======== 4 6 ========
# ======== original ========
#               動画時間_correct    経過日数  プレミア公開   視聴回数    コメント  高評価件数  低評価件数
# 動画時間_correct        1.0000 -0.4725  0.6778 0.3289  0.4521 0.4101 0.1251
# 経過日数               -0.4725  1.0000 -0.6418 0.1271 -0.0774 0.0095 0.2587
# プレミア公開              0.6778 -0.6418  1.0000 0.2140  0.3776 0.3293 0.1649
# 視聴回数                0.3289  0.1271  0.2140 1.0000  0.8486 0.9104 0.8311
# コメント                0.4521 -0.0774  0.3776 0.8486  1.0000 0.8322 0.6137
# 高評価件数               0.4101  0.0095  0.3293 0.9104  0.8322 1.0000 0.6606
# 低評価件数               0.1251  0.2587  0.1649 0.8311  0.6137 0.6606 1.0000
# ======== estimated ========
#               動画時間_correct    経過日数  プレミア公開    視聴回数    コメント   高評価件数   低評価件数
# 動画時間_correct        1.0000 -0.4350  0.6778  0.0052  0.0046  0.0052  0.0042
# 経過日数               -0.4350  1.0000 -0.6418 -0.0049 -0.0044 -0.0049 -0.0039
# プレミア公開              0.6778 -0.6418  1.0000  0.0059  0.0052  0.0059  0.0047
# 視聴回数                0.0052 -0.0049  0.0059  1.0000  0.8486  0.9104  0.8311
# コメント                0.0046 -0.0044  0.0052  0.8486  1.0000  0.7726  0.7053
# 高評価件数               0.0052 -0.0049  0.0059  0.9104  0.7726  1.0000  0.6606
# 低評価件数               0.0042 -0.0039  0.0047  0.8311  0.7053  0.6606  1.0000
# ======== test rel to original ========
# dev: 6.675590405027713
# p: 0.9660347651644356
# ======== test rel to prev ========
# dev: 0.7141214434260776
# p: 0.3980789785648776

# %%
print('inverse of correlation')
pd.DataFrame(inverse_cor(estimated_cors[-1]), index=df_cor.columns, columns=df_cor.columns)
# Out:
# inverse of correlation
#               動画時間_correct    経過日数  プレミア公開    視聴回数    コメント   高評価件数   低評価件数
# 動画時間_correct        1.0000  0.0000 -0.5773 -0.0001 -0.0002 -0.0003  0.0000
# 経過日数                0.0000  1.0000  0.5241  0.0001  0.0002  0.0003 -0.0000
# プレミア公開             -0.5773  0.5241  1.0000 -0.0001  0.0000 -0.0005 -0.0002
# 視聴回数               -0.0001  0.0001 -0.0001  1.0000 -0.4078 -0.7903 -0.6753
# コメント               -0.0002  0.0002  0.0000 -0.4078  1.0000 -0.0000  0.0000
# 高評価件数              -0.0003  0.0003 -0.0005 -0.7903 -0.0000  1.0000  0.4176
# 低評価件数               0.0000 -0.0000 -0.0002 -0.6753 -0.0000  0.4176  1.0000

# %%
cond_ind_pairs = [(1, 4), (4, 5), (0, 1), (0, 4), (0, 5), (1, 5), (1, 3), (0, 3), (2, 5), (2, 3), (2, 6), (0, 6), (1, 6), (2, 4), (4, 6), (5, 6)]
# estimated_cors = [df_cor.values]

estimated_cors.append(estimate(estimated_cors[-1], cond_ind_pairs))

print('========', 'original', '========')
df_original = pd.DataFrame(estimated_cors[0], index=df_cor.columns, columns=df_cor.columns)
display(df_original)

print('========', 'estimated', '========')
df_estimated = pd.DataFrame(estimated_cors[-1], index=df_cor.columns, columns=df_cor.columns)
display(df_estimated)


print('========', 'test rel to original', '========')
dev, p = deviance_and_p(estimated_cors[0], estimated_cors[-1], df=len(cond_ind_pairs))
print('dev:', dev)
print('p:', 1 - p)

print('========', 'test rel to prev', '========')
dev, p = deviance_and_p(estimated_cors[-2], estimated_cors[-1], df=1)
print('dev:', dev)
print('p:', 1 - p)
# Out:
# ======== 0 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
#      ======== 4 6 ========
#      ======== 5 6 ========
# ======== 1 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
#      ======== 4 6 ========
#      ======== 5 6 ========
# ======== 2 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
#      ======== 4 6 ========
#      ======== 5 6 ========
# ======== 3 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
#      ======== 4 6 ========
#      ======== 5 6 ========
# ======== 4 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
#      ======== 4 6 ========
#      ======== 5 6 ========
# ======== 5 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
#      ======== 4 6 ========
#      ======== 5 6 ========
# ======== 6 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
#      ======== 4 6 ========
#      ======== 5 6 ========
# ======== 7 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
#      ======== 4 6 ========
#      ======== 5 6 ========
# ======== 8 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
#      ======== 4 6 ========
#      ======== 5 6 ========
# ======== 9 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
#      ======== 4 6 ========
#      ======== 5 6 ========
# ======== 10 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
#      ======== 4 6 ========
#      ======== 5 6 ========
# ======== 11 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
#      ======== 4 6 ========
#      ======== 5 6 ========
# ======== original ========
#               動画時間_correct    経過日数  プレミア公開   視聴回数    コメント  高評価件数  低評価件数
# 動画時間_correct        1.0000 -0.4725  0.6778 0.3289  0.4521 0.4101 0.1251
# 経過日数               -0.4725  1.0000 -0.6418 0.1271 -0.0774 0.0095 0.2587
# プレミア公開              0.6778 -0.6418  1.0000 0.2140  0.3776 0.3293 0.1649
# 視聴回数                0.3289  0.1271  0.2140 1.0000  0.8486 0.9104 0.8311
# コメント                0.4521 -0.0774  0.3776 0.8486  1.0000 0.8322 0.6137
# 高評価件数               0.4101  0.0095  0.3293 0.9104  0.8322 1.0000 0.6606
# 低評価件数               0.1251  0.2587  0.1649 0.8311  0.6137 0.6606 1.0000
# ======== estimated ========
#               動画時間_correct    経過日数  プレミア公開    視聴回数    コメント   高評価件数   低評価件数
# 動画時間_correct        1.0000 -0.4350  0.6778  0.0040  0.0036  0.0040  0.0034
# 経過日数               -0.4350  1.0000 -0.6418 -0.0038 -0.0034 -0.0038 -0.0032
# プレミア公開              0.6778 -0.6418  1.0000  0.0045  0.0040  0.0045  0.0039
# 視聴回数                0.0040 -0.0038  0.0045  1.0000  0.8486  0.9104  0.8311
# コメント                0.0036 -0.0034  0.0040  0.8486  1.0000  0.7726  0.7053
# 高評価件数               0.0040 -0.0038  0.0045  0.9104  0.7726  1.0000  0.7566
# 低評価件数               0.0034 -0.0032  0.0039  0.8311  0.7053  0.7566  1.0000
# ======== test rel to original ========
# dev: 8.0169379517775
# p: 0.9483605361453541
# ======== test rel to prev ========
# dev: 1.3413475467497866
# p: 0.2467964653921485

# %%
print('inverse of correlation')
pd.DataFrame(inverse_cor(estimated_cors[-1]), index=df_cor.columns, columns=df_cor.columns)
# Out:
# inverse of correlation
#               動画時間_correct   経過日数  プレミア公開    視聴回数    コメント   高評価件数   低評価件数
# 動画時間_correct        1.0000 0.0000 -0.5773 -0.0001 -0.0002 -0.0003 -0.0000
# 経過日数                0.0000 1.0000  0.5241  0.0001  0.0002  0.0003  0.0000
# プレミア公開             -0.5773 0.5241  1.0000 -0.0001 -0.0000 -0.0003 -0.0002
# 視聴回数               -0.0001 0.0001 -0.0001  1.0000 -0.4916 -0.6743 -0.4580
# コメント               -0.0002 0.0002 -0.0000 -0.4916  1.0000  0.0000  0.0000
# 高評価件数              -0.0003 0.0003 -0.0003 -0.6743  0.0000  1.0000  0.0000
# 低評価件数              -0.0000 0.0000 -0.0002 -0.4580  0.0000  0.0000  1.0000

# %%
cond_ind_pairs = [(1, 4), (4, 5), (0, 1), (0, 4), (0, 5), (1, 5), (1, 3), (0, 3), (2, 5), (2, 3), (2, 6), (0, 6), (1, 6), (2, 4), (4, 6), (5, 6), (3, 4)]
# estimated_cors = [df_cor.values]

estimated_cors.append(estimate(estimated_cors[-1], cond_ind_pairs))

print('========', 'original', '========')
df_original = pd.DataFrame(estimated_cors[0], index=df_cor.columns, columns=df_cor.columns)
display(df_original)

print('========', 'estimated', '========')
df_estimated = pd.DataFrame(estimated_cors[-1], index=df_cor.columns, columns=df_cor.columns)
display(df_estimated)


print('========', 'test rel to original', '========')
dev, p = deviance_and_p(estimated_cors[0], estimated_cors[-1], df=len(cond_ind_pairs))
print('dev:', dev)
print('p:', 1 - p)

print('========', 'test rel to prev', '========')
dev, p = deviance_and_p(estimated_cors[-2], estimated_cors[-1], df=1)
print('dev:', dev)
print('p:', 1 - p)
# Out:
# ======== 0 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
#      ======== 4 6 ========
#      ======== 5 6 ========
#      ======== 3 4 ========
# ======== 1 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
#      ======== 4 6 ========
#      ======== 5 6 ========
#      ======== 3 4 ========
# ======== 2 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
#      ======== 4 6 ========
#      ======== 5 6 ========
#      ======== 3 4 ========
# ======== 3 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
#      ======== 4 6 ========
#      ======== 5 6 ========
#      ======== 3 4 ========
# ======== 4 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
#      ======== 4 6 ========
#      ======== 5 6 ========
#      ======== 3 4 ========
# ======== 5 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
#      ======== 4 6 ========
#      ======== 5 6 ========
#      ======== 3 4 ========
# ======== 6 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
#      ======== 4 6 ========
#      ======== 5 6 ========
#      ======== 3 4 ========
# ======== 7 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
#      ======== 4 6 ========
#      ======== 5 6 ========
#      ======== 3 4 ========
# ======== 8 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
#      ======== 4 6 ========
#      ======== 5 6 ========
#      ======== 3 4 ========
# ======== 9 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
#      ======== 4 6 ========
#      ======== 5 6 ========
#      ======== 3 4 ========
# ======== 10 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
#      ======== 4 6 ========
#      ======== 5 6 ========
#      ======== 3 4 ========
# ======== 11 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
#      ======== 4 6 ========
#      ======== 5 6 ========
#      ======== 3 4 ========
# ======== 12 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
#      ======== 4 6 ========
#      ======== 5 6 ========
#      ======== 3 4 ========
# ======== 13 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
#      ======== 4 6 ========
#      ======== 5 6 ========
#      ======== 3 4 ========
# ======== 14 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
#      ======== 4 6 ========
#      ======== 5 6 ========
#      ======== 3 4 ========
# ======== 15 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
#      ======== 4 6 ========
#      ======== 5 6 ========
#      ======== 3 4 ========
# ======== 16 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
#      ======== 4 6 ========
#      ======== 5 6 ========
#      ======== 3 4 ========
# ======== 17 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
#      ======== 4 6 ========
#      ======== 5 6 ========
#      ======== 3 4 ========
# ======== 18 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
#      ======== 4 6 ========
#      ======== 5 6 ========
#      ======== 3 4 ========
# ======== 19 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
#      ======== 4 6 ========
#      ======== 5 6 ========
#      ======== 3 4 ========
# ======== 20 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
#      ======== 4 6 ========
#      ======== 5 6 ========
#      ======== 3 4 ========
# ======== 21 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
#      ======== 4 6 ========
#      ======== 5 6 ========
#      ======== 3 4 ========
# ======== 22 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
#      ======== 4 6 ========
#      ======== 5 6 ========
#      ======== 3 4 ========
# ======== 23 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
#      ======== 4 6 ========
#      ======== 5 6 ========
#      ======== 3 4 ========
# ======== 24 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
#      ======== 4 6 ========
#      ======== 5 6 ========
#      ======== 3 4 ========
# ======== 25 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
#      ======== 4 6 ========
#      ======== 5 6 ========
#      ======== 3 4 ========
# ======== 26 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
#      ======== 4 6 ========
#      ======== 5 6 ========
#      ======== 3 4 ========
# ======== 27 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
#      ======== 4 6 ========
#      ======== 5 6 ========
#      ======== 3 4 ========
# ======== 28 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
#      ======== 4 6 ========
#      ======== 5 6 ========
#      ======== 3 4 ========
# ======== 29 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
#      ======== 4 6 ========
#      ======== 5 6 ========
#      ======== 3 4 ========
# ======== 30 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
#      ======== 4 6 ========
#      ======== 5 6 ========
#      ======== 3 4 ========
# ======== 31 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
#      ======== 4 6 ========
#      ======== 5 6 ========
#      ======== 3 4 ========
# ======== 32 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
#      ======== 4 6 ========
#      ======== 5 6 ========
#      ======== 3 4 ========
# ======== 33 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
#      ======== 4 6 ========
#      ======== 5 6 ========
#      ======== 3 4 ========
# ======== 34 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
#      ======== 4 6 ========
#      ======== 5 6 ========
#      ======== 3 4 ========
# ======== 35 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
#      ======== 4 6 ========
#      ======== 5 6 ========
#      ======== 3 4 ========
# ======== 36 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
#      ======== 4 6 ========
#      ======== 5 6 ========
#      ======== 3 4 ========
# ======== 37 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
#      ======== 4 6 ========
#      ======== 5 6 ========
#      ======== 3 4 ========
# ======== 38 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
#      ======== 4 6 ========
#      ======== 5 6 ========
#      ======== 3 4 ========
# ======== 39 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
#      ======== 4 6 ========
#      ======== 5 6 ========
#      ======== 3 4 ========
# ======== 40 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
#      ======== 4 6 ========
#      ======== 5 6 ========
#      ======== 3 4 ========
# ======== 41 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
#      ======== 4 6 ========
#      ======== 5 6 ========
#      ======== 3 4 ========
# ======== 42 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
#      ======== 4 6 ========
#      ======== 5 6 ========
#      ======== 3 4 ========
# ======== 43 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
#      ======== 4 6 ========
#      ======== 5 6 ========
#      ======== 3 4 ========
# ======== 44 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
#      ======== 4 6 ========
#      ======== 5 6 ========
#      ======== 3 4 ========
# ======== 45 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
#      ======== 4 6 ========
#      ======== 5 6 ========
#      ======== 3 4 ========
# ======== 46 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
#      ======== 4 6 ========
#      ======== 5 6 ========
#      ======== 3 4 ========
# ======== 47 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
#      ======== 4 6 ========
#      ======== 5 6 ========
#      ======== 3 4 ========
# ======== 48 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
#      ======== 4 6 ========
#      ======== 5 6 ========
#      ======== 3 4 ========
# ======== 49 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
#      ======== 4 6 ========
#      ======== 5 6 ========
#      ======== 3 4 ========
# ======== 50 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
#      ======== 4 6 ========
#      ======== 5 6 ========
#      ======== 3 4 ========
# ======== 51 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
#      ======== 4 6 ========
#      ======== 5 6 ========
#      ======== 3 4 ========
# ======== 52 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
#      ======== 4 6 ========
#      ======== 5 6 ========
#      ======== 3 4 ========
# ======== 53 -th iteration ========
#      ======== 1 4 ========
#      ======== 4 5 ========
#      ======== 0 1 ========
#      ======== 0 4 ========
#      ======== 0 5 ========
#      ======== 1 5 ========
#      ======== 1 3 ========
#      ======== 0 3 ========
#      ======== 2 5 ========
#      ======== 2 3 ========
#      ======== 2 6 ========
#      ======== 0 6 ========
#      ======== 1 6 ========
#      ======== 2 4 ========
#      ======== 4 6 ========
#      ======== 5 6 ========
#      ======== 3 4 ========
# ======== original ========
#               動画時間_correct    経過日数  プレミア公開   視聴回数    コメント  高評価件数  低評価件数
# 動画時間_correct        1.0000 -0.4725  0.6778 0.3289  0.4521 0.4101 0.1251
# 経過日数               -0.4725  1.0000 -0.6418 0.1271 -0.0774 0.0095 0.2587
# プレミア公開              0.6778 -0.6418  1.0000 0.2140  0.3776 0.3293 0.1649
# 視聴回数                0.3289  0.1271  0.2140 1.0000  0.8486 0.9104 0.8311
# コメント                0.4521 -0.0774  0.3776 0.8486  1.0000 0.8322 0.6137
# 高評価件数               0.4101  0.0095  0.3293 0.9104  0.8322 1.0000 0.6606
# 低評価件数               0.1251  0.2587  0.1649 0.8311  0.6137 0.6606 1.0000
# ======== estimated ========
#               動画時間_correct    経過日数  プレミア公開    視聴回数    コメント   高評価件数   低評価件数
# 動画時間_correct        1.0000 -0.4350  0.6778  0.0009  0.0000  0.0009  0.0008
# 経過日数               -0.4350  1.0000 -0.6418 -0.0008 -0.0000 -0.0009 -0.0007
# プレミア公開              0.6778 -0.6418  1.0000  0.0010  0.0000  0.0010  0.0009
# 視聴回数                0.0009 -0.0008  0.0010  1.0000  0.0007  0.9104  0.8311
# コメント                0.0000 -0.0000  0.0000  0.0007  1.0000  0.0007  0.0006
# 高評価件数               0.0009 -0.0009  0.0010  0.9104  0.0007  1.0000  0.7566
# 低評価件数               0.0008 -0.0007  0.0009  0.8311  0.0006  0.7566  1.0000
# ======== test rel to original ========
# dev: 16.93091705656749
# p: 0.4590559679417151
# ======== test rel to prev ========
# dev: 8.913979104789991
# p: 0.0028299596843852637

# %% [markdown]
# ## 2nd trial

# %%
idxs = [0, 3, 4, 5, 6]
column_names = df_cor.columns[idxs]
estimated_cors = [df_cor.values[idxs][:, idxs]]
cond_ind_pairs = []

estimated_cors.append(estimate(estimated_cors[-1], cond_ind_pairs))

print('========', 'original', '========')
df_original = pd.DataFrame(estimated_cors[0], index=column_names, columns=column_names)
display(df_original)

print('========', 'estimated', '========')
df_estimated = pd.DataFrame(estimated_cors[-1], index=column_names, columns=column_names)
display(df_estimated)


print('========', 'test rel to original', '========')
dev, p = deviance_and_p(estimated_cors[0], estimated_cors[-1], df=len(cond_ind_pairs))
print('dev:', dev)
print('p:', 1 - p)

print('========', 'test rel to prev', '========')
dev, p = deviance_and_p(estimated_cors[-2], estimated_cors[-1], df=1)
print('dev:', dev)
print('p:', 1 - p)
# Out:
# ======== 0 -th iteration ========
# ======== original ========
#               動画時間_correct   視聴回数   コメント  高評価件数  低評価件数
# 動画時間_correct        1.0000 0.3289 0.4521 0.4101 0.1251
# 視聴回数                0.3289 1.0000 0.8486 0.9104 0.8311
# コメント                0.4521 0.8486 1.0000 0.8322 0.6137
# 高評価件数               0.4101 0.9104 0.8322 1.0000 0.6606
# 低評価件数               0.1251 0.8311 0.6137 0.6606 1.0000
# ======== estimated ========
#               動画時間_correct   視聴回数   コメント  高評価件数  低評価件数
# 動画時間_correct        1.0000 0.3289 0.4521 0.4101 0.1251
# 視聴回数                0.3289 1.0000 0.8486 0.9104 0.8311
# コメント                0.4521 0.8486 1.0000 0.8322 0.6137
# 高評価件数               0.4101 0.9104 0.8322 1.0000 0.6606
# 低評価件数               0.1251 0.8311 0.6137 0.6606 1.0000
# ======== test rel to original ========
# dev: 0.0
# p: nan
# ======== test rel to prev ========
# dev: 0.0
# p: 1.0

# %%
print('inverse of correlation')
pd.DataFrame(inverse_cor(estimated_cors[-1]), index=column_names, columns=column_names)
# Out:
# inverse of correlation
#               動画時間_correct    視聴回数    コメント   高評価件数   低評価件数
# 動画時間_correct        1.0000  0.0577 -0.2602 -0.1509  0.1315
# 視聴回数                0.0577  1.0000 -0.4250 -0.7019 -0.7329
# コメント               -0.2602 -0.4250  1.0000 -0.1184  0.1821
# 高評価件数              -0.1509 -0.7019 -0.1184  1.0000  0.3367
# 低評価件数               0.1315 -0.7329  0.1821  0.3367  1.0000

# %%
cond_ind_pairs = [(0, 1)]

estimated_cors.append(estimate(estimated_cors[-1], cond_ind_pairs))

print('========', 'original', '========')
df_original = pd.DataFrame(estimated_cors[0], index=column_names, columns=column_names)
display(df_original)

print('========', 'estimated', '========')
df_estimated = pd.DataFrame(estimated_cors[-1], index=column_names, columns=column_names)
display(df_estimated)


print('========', 'test rel to original', '========')
dev, p = deviance_and_p(estimated_cors[0], estimated_cors[-1], df=len(cond_ind_pairs))
print('dev:', dev)
print('p:', 1 - p)

print('========', 'test rel to prev', '========')
dev, p = deviance_and_p(estimated_cors[-2], estimated_cors[-1], df=1)
print('dev:', dev)
print('p:', 1 - p)
# Out:
# ======== 0 -th iteration ========
#      ======== 0 1 ========
# ======== 1 -th iteration ========
#      ======== 0 1 ========
# ======== original ========
#               動画時間_correct   視聴回数   コメント  高評価件数  低評価件数
# 動画時間_correct        1.0000 0.3289 0.4521 0.4101 0.1251
# 視聴回数                0.3289 1.0000 0.8486 0.9104 0.8311
# コメント                0.4521 0.8486 1.0000 0.8322 0.6137
# 高評価件数               0.4101 0.9104 0.8322 1.0000 0.6606
# 低評価件数               0.1251 0.8311 0.6137 0.6606 1.0000
# ======== estimated ========
#               動画時間_correct   視聴回数   コメント  高評価件数  低評価件数
# 動画時間_correct        1.0000 0.3414 0.4521 0.4101 0.1251
# 視聴回数                0.3414 1.0000 0.8486 0.9104 0.8311
# コメント                0.4521 0.8486 1.0000 0.8322 0.6137
# 高評価件数               0.4101 0.9104 0.8322 1.0000 0.6606
# 低評価件数               0.1251 0.8311 0.6137 0.6606 1.0000
# ======== test rel to original ========
# dev: 0.01664772810728632
# p: 0.8973370161750143
# ======== test rel to prev ========
# dev: 0.01664772810728632
# p: 0.8973370161750143

# %%
print('inverse of correlation')
pd.DataFrame(inverse_cor(estimated_cors[-1]), index=column_names, columns=column_names)
# Out:
# inverse of correlation
#               動画時間_correct    視聴回数    コメント   高評価件数   低評価件数
# 動画時間_correct        1.0000 -0.0000 -0.2375 -0.1112  0.1729
# 視聴回数               -0.0000  1.0000 -0.4131 -0.6980 -0.7369
# コメント               -0.2375 -0.4131  1.0000 -0.1330  0.1751
# 高評価件数              -0.1112 -0.6980 -0.1330  1.0000  0.3369
# 低評価件数               0.1729 -0.7369  0.1751  0.3369  1.0000

# %%
cond_ind_pairs = [(0, 1), (0, 3)]

estimated_cors.append(estimate(estimated_cors[-1], cond_ind_pairs))

print('========', 'original', '========')
df_original = pd.DataFrame(estimated_cors[0], index=column_names, columns=column_names)
display(df_original)

print('========', 'estimated', '========')
df_estimated = pd.DataFrame(estimated_cors[-1], index=column_names, columns=column_names)
display(df_estimated)


print('========', 'test rel to original', '========')
dev, p = deviance_and_p(estimated_cors[0], estimated_cors[-1], df=len(cond_ind_pairs))
print('dev:', dev)
print('p:', 1 - p)

print('========', 'test rel to prev', '========')
dev, p = deviance_and_p(estimated_cors[-2], estimated_cors[-1], df=1)
print('dev:', dev)
print('p:', 1 - p)
# Out:
# ======== 0 -th iteration ========
#      ======== 0 1 ========
#      ======== 0 3 ========
# ======== 1 -th iteration ========
#      ======== 0 1 ========
#      ======== 0 3 ========
# ======== 2 -th iteration ========
#      ======== 0 1 ========
#      ======== 0 3 ========
# ======== 3 -th iteration ========
#      ======== 0 1 ========
#      ======== 0 3 ========
# ======== 4 -th iteration ========
#      ======== 0 1 ========
#      ======== 0 3 ========
# ======== 5 -th iteration ========
#      ======== 0 1 ========
#      ======== 0 3 ========
# ======== 6 -th iteration ========
#      ======== 0 1 ========
#      ======== 0 3 ========
# ======== 7 -th iteration ========
#      ======== 0 1 ========
#      ======== 0 3 ========
# ======== 8 -th iteration ========
#      ======== 0 1 ========
#      ======== 0 3 ========
# ======== 9 -th iteration ========
#      ======== 0 1 ========
#      ======== 0 3 ========
# ======== original ========
#               動画時間_correct   視聴回数   コメント  高評価件数  低評価件数
# 動画時間_correct        1.0000 0.3289 0.4521 0.4101 0.1251
# 視聴回数                0.3289 1.0000 0.8486 0.9104 0.8311
# コメント                0.4521 0.8486 1.0000 0.8322 0.6137
# 高評価件数               0.4101 0.9104 0.8322 1.0000 0.6606
# 低評価件数               0.1251 0.8311 0.6137 0.6606 1.0000
# ======== estimated ========
#               動画時間_correct   視聴回数   コメント  高評価件数  低評価件数
# 動画時間_correct        1.0000 0.3079 0.4521 0.3397 0.1251
# 視聴回数                0.3079 1.0000 0.8486 0.9104 0.8311
# コメント                0.4521 0.8486 1.0000 0.8322 0.6137
# 高評価件数               0.3397 0.9104 0.8322 1.0000 0.6606
# 低評価件数               0.1251 0.8311 0.6137 0.6606 1.0000
# ======== test rel to original ========
# dev: 0.13877981381835713
# p: 0.9329628404935122
# ======== test rel to prev ========
# dev: 0.12213208571107081
# p: 0.7267334771117406

# %%
print('inverse of correlation')
pd.DataFrame(inverse_cor(estimated_cors[-1]), index=column_names, columns=column_names)
# Out:
# inverse of correlation
#               動画時間_correct    視聴回数    コメント   高評価件数   低評価件数
# 動画時間_correct        1.0000 -0.0001 -0.3242  0.0000  0.1370
# 視聴回数               -0.0001  1.0000 -0.4023 -0.7024 -0.7412
# コメント               -0.3242 -0.4023  1.0000 -0.1562  0.1674
# 高評価件数               0.0000 -0.7024 -0.1562  1.0000  0.3604
# 低評価件数               0.1370 -0.7412  0.1674  0.3604  1.0000

# %%
cond_ind_pairs = [(0, 1), (0, 3), (0, 4)]

estimated_cors.append(estimate(estimated_cors[-1], cond_ind_pairs))

print('========', 'original', '========')
df_original = pd.DataFrame(estimated_cors[0], index=column_names, columns=column_names)
display(df_original)

print('========', 'estimated', '========')
df_estimated = pd.DataFrame(estimated_cors[-1], index=column_names, columns=column_names)
display(df_estimated)


print('========', 'test rel to original', '========')
dev, p = deviance_and_p(estimated_cors[0], estimated_cors[-1], df=len(cond_ind_pairs))
print('dev:', dev)
print('p:', 1 - p)

print('========', 'test rel to prev', '========')
dev, p = deviance_and_p(estimated_cors[-2], estimated_cors[-1], df=1)
print('dev:', dev)
print('p:', 1 - p)
# Out:
# ======== 0 -th iteration ========
#      ======== 0 1 ========
#      ======== 0 3 ========
#      ======== 0 4 ========
# ======== 1 -th iteration ========
#      ======== 0 1 ========
#      ======== 0 3 ========
#      ======== 0 4 ========
# ======== 2 -th iteration ========
#      ======== 0 1 ========
#      ======== 0 3 ========
#      ======== 0 4 ========
# ======== 3 -th iteration ========
#      ======== 0 1 ========
#      ======== 0 3 ========
#      ======== 0 4 ========
# ======== 4 -th iteration ========
#      ======== 0 1 ========
#      ======== 0 3 ========
#      ======== 0 4 ========
# ======== 5 -th iteration ========
#      ======== 0 1 ========
#      ======== 0 3 ========
#      ======== 0 4 ========
# ======== 6 -th iteration ========
#      ======== 0 1 ========
#      ======== 0 3 ========
#      ======== 0 4 ========
# ======== 7 -th iteration ========
#      ======== 0 1 ========
#      ======== 0 3 ========
#      ======== 0 4 ========
# ======== 8 -th iteration ========
#      ======== 0 1 ========
#      ======== 0 3 ========
#      ======== 0 4 ========
# ======== 9 -th iteration ========
#      ======== 0 1 ========
#      ======== 0 3 ========
#      ======== 0 4 ========
# ======== 10 -th iteration ========
#      ======== 0 1 ========
#      ======== 0 3 ========
#      ======== 0 4 ========
# ======== 11 -th iteration ========
#      ======== 0 1 ========
#      ======== 0 3 ========
#      ======== 0 4 ========
# ======== 12 -th iteration ========
#      ======== 0 1 ========
#      ======== 0 3 ========
#      ======== 0 4 ========
# ======== 13 -th iteration ========
#      ======== 0 1 ========
#      ======== 0 3 ========
#      ======== 0 4 ========
# ======== 14 -th iteration ========
#      ======== 0 1 ========
#      ======== 0 3 ========
#      ======== 0 4 ========
# ======== 15 -th iteration ========
#      ======== 0 1 ========
#      ======== 0 3 ========
#      ======== 0 4 ========
# ======== 16 -th iteration ========
#      ======== 0 1 ========
#      ======== 0 3 ========
#      ======== 0 4 ========
# ======== 17 -th iteration ========
#      ======== 0 1 ========
#      ======== 0 3 ========
#      ======== 0 4 ========
# ======== 18 -th iteration ========
#      ======== 0 1 ========
#      ======== 0 3 ========
#      ======== 0 4 ========
# ======== 19 -th iteration ========
#      ======== 0 1 ========
#      ======== 0 3 ========
#      ======== 0 4 ========
# ======== original ========
#               動画時間_correct   視聴回数   コメント  高評価件数  低評価件数
# 動画時間_correct        1.0000 0.3289 0.4521 0.4101 0.1251
# 視聴回数                0.3289 1.0000 0.8486 0.9104 0.8311
# コメント                0.4521 0.8486 1.0000 0.8322 0.6137
# 高評価件数               0.4101 0.9104 0.8322 1.0000 0.6606
# 低評価件数               0.1251 0.8311 0.6137 0.6606 1.0000
# ======== estimated ========
#               動画時間_correct   視聴回数   コメント  高評価件数  低評価件数
# 動画時間_correct        1.0000 0.3835 0.4521 0.3761 0.2772
# 視聴回数                0.3835 1.0000 0.8486 0.9104 0.8311
# コメント                0.4521 0.8486 1.0000 0.8322 0.6137
# 高評価件数               0.3761 0.9104 0.8322 1.0000 0.6606
# 低評価件数               0.2772 0.8311 0.6137 0.6606 1.0000
# ======== test rel to original ========
# dev: 0.3785010918945497
# p: 0.9446469677793985
# ======== test rel to prev ========
# dev: 0.2397212780761926
# p: 0.6244074949113918

# %%
print('inverse of correlation')
pd.DataFrame(inverse_cor(estimated_cors[-1]), index=column_names, columns=column_names)
# Out:
# inverse of correlation
#               動画時間_correct    視聴回数    コメント   高評価件数   低評価件数
# 動画時間_correct        1.0000  0.0002 -0.2440 -0.0001 -0.0000
# 視聴回数                0.0002  1.0000 -0.4125 -0.7024 -0.7482
# コメント               -0.2440 -0.4125  1.0000 -0.1602  0.2192
# 高評価件数              -0.0001 -0.7024 -0.1602  1.0000  0.3639
# 低評価件数              -0.0000 -0.7482  0.2192  0.3639  1.0000

# %%
cond_ind_pairs = [(0, 1), (0, 3), (0, 4), (2, 3)]

estimated_cors.append(estimate(estimated_cors[-1], cond_ind_pairs))

print('========', 'original', '========')
df_original = pd.DataFrame(estimated_cors[0], index=column_names, columns=column_names)
display(df_original)

print('========', 'estimated', '========')
df_estimated = pd.DataFrame(estimated_cors[-1], index=column_names, columns=column_names)
display(df_estimated)


print('========', 'test rel to original', '========')
dev, p = deviance_and_p(estimated_cors[0], estimated_cors[-1], df=len(cond_ind_pairs))
print('dev:', dev)
print('p:', 1 - p)

print('========', 'test rel to prev', '========')
dev, p = deviance_and_p(estimated_cors[-2], estimated_cors[-1], df=1)
print('dev:', dev)
print('p:', 1 - p)
# Out:
# ======== 0 -th iteration ========
#      ======== 0 1 ========
#      ======== 0 3 ========
#      ======== 0 4 ========
#      ======== 2 3 ========
# ======== 1 -th iteration ========
#      ======== 0 1 ========
#      ======== 0 3 ========
#      ======== 0 4 ========
#      ======== 2 3 ========
# ======== 2 -th iteration ========
#      ======== 0 1 ========
#      ======== 0 3 ========
#      ======== 0 4 ========
#      ======== 2 3 ========
# ======== 3 -th iteration ========
#      ======== 0 1 ========
#      ======== 0 3 ========
#      ======== 0 4 ========
#      ======== 2 3 ========
# ======== 4 -th iteration ========
#      ======== 0 1 ========
#      ======== 0 3 ========
#      ======== 0 4 ========
#      ======== 2 3 ========
# ======== 5 -th iteration ========
#      ======== 0 1 ========
#      ======== 0 3 ========
#      ======== 0 4 ========
#      ======== 2 3 ========
# ======== 6 -th iteration ========
#      ======== 0 1 ========
#      ======== 0 3 ========
#      ======== 0 4 ========
#      ======== 2 3 ========
# ======== 7 -th iteration ========
#      ======== 0 1 ========
#      ======== 0 3 ========
#      ======== 0 4 ========
#      ======== 2 3 ========
# ======== 8 -th iteration ========
#      ======== 0 1 ========
#      ======== 0 3 ========
#      ======== 0 4 ========
#      ======== 2 3 ========
# ======== 9 -th iteration ========
#      ======== 0 1 ========
#      ======== 0 3 ========
#      ======== 0 4 ========
#      ======== 2 3 ========
# ======== 10 -th iteration ========
#      ======== 0 1 ========
#      ======== 0 3 ========
#      ======== 0 4 ========
#      ======== 2 3 ========
# ======== 11 -th iteration ========
#      ======== 0 1 ========
#      ======== 0 3 ========
#      ======== 0 4 ========
#      ======== 2 3 ========
# ======== 12 -th iteration ========
#      ======== 0 1 ========
#      ======== 0 3 ========
#      ======== 0 4 ========
#      ======== 2 3 ========
# ======== 13 -th iteration ========
#      ======== 0 1 ========
#      ======== 0 3 ========
#      ======== 0 4 ========
#      ======== 2 3 ========
# ======== 14 -th iteration ========
#      ======== 0 1 ========
#      ======== 0 3 ========
#      ======== 0 4 ========
#      ======== 2 3 ========
# ======== original ========
#               動画時間_correct   視聴回数   コメント  高評価件数  低評価件数
# 動画時間_correct        1.0000 0.3289 0.4521 0.4101 0.1251
# 視聴回数                0.3289 1.0000 0.8486 0.9104 0.8311
# コメント                0.4521 0.8486 1.0000 0.8322 0.6137
# 高評価件数               0.4101 0.9104 0.8322 1.0000 0.6606
# 低評価件数               0.1251 0.8311 0.6137 0.6606 1.0000
# ======== estimated ========
#               動画時間_correct   視聴回数   コメント  高評価件数  低評価件数
# 動画時間_correct        1.0000 0.3839 0.4521 0.3623 0.2777
# 視聴回数                0.3839 1.0000 0.8486 0.9104 0.8311
# コメント                0.4521 0.8486 1.0000 0.8010 0.6137
# 高評価件数               0.3623 0.9104 0.8010 1.0000 0.6606
# 低評価件数               0.2777 0.8311 0.6137 0.6606 1.0000
# ======== test rel to original ========
# dev: 0.516790307478403
# p: 0.9718459914227738
# ======== test rel to prev ========
# dev: 0.13828921558385332
# p: 0.7099877215645511

# %%
print('inverse of correlation')
pd.DataFrame(inverse_cor(estimated_cors[-1]), index=column_names, columns=column_names)
# Out:
# inverse of correlation
#               動画時間_correct    視聴回数    コメント   高評価件数   低評価件数
# 動画時間_correct        1.0000 -0.0003 -0.2466  0.0001  0.0000
# 視聴回数               -0.0003  1.0000 -0.5025 -0.7401 -0.7541
# コメント               -0.2466 -0.5025  1.0000  0.0000  0.2766
# 高評価件数               0.0001 -0.7401 -0.0000  1.0000  0.4002
# 低評価件数               0.0000 -0.7541  0.2766  0.4002  1.0000

# %%
cond_ind_pairs = [(0, 1), (0, 3), (0, 4), (2, 3), (2, 4)]

estimated_cors.append(estimate(estimated_cors[-1], cond_ind_pairs))

print('========', 'original', '========')
df_original = pd.DataFrame(estimated_cors[0], index=column_names, columns=column_names)
display(df_original)

print('========', 'estimated', '========')
df_estimated = pd.DataFrame(estimated_cors[-1], index=column_names, columns=column_names)
display(df_estimated)


print('========', 'test rel to original', '========')
dev, p = deviance_and_p(estimated_cors[0], estimated_cors[-1], df=len(cond_ind_pairs))
print('dev:', dev)
print('p:', 1 - p)

print('========', 'test rel to prev', '========')
dev, p = deviance_and_p(estimated_cors[-2], estimated_cors[-1], df=1)
print('dev:', dev)
print('p:', 1 - p)
# Out:
# ======== 0 -th iteration ========
#      ======== 0 1 ========
#      ======== 0 3 ========
#      ======== 0 4 ========
#      ======== 2 3 ========
#      ======== 2 4 ========
# ======== 1 -th iteration ========
#      ======== 0 1 ========
#      ======== 0 3 ========
#      ======== 0 4 ========
#      ======== 2 3 ========
#      ======== 2 4 ========
# ======== 2 -th iteration ========
#      ======== 0 1 ========
#      ======== 0 3 ========
#      ======== 0 4 ========
#      ======== 2 3 ========
#      ======== 2 4 ========
# ======== 3 -th iteration ========
#      ======== 0 1 ========
#      ======== 0 3 ========
#      ======== 0 4 ========
#      ======== 2 3 ========
#      ======== 2 4 ========
# ======== 4 -th iteration ========
#      ======== 0 1 ========
#      ======== 0 3 ========
#      ======== 0 4 ========
#      ======== 2 3 ========
#      ======== 2 4 ========
# ======== 5 -th iteration ========
#      ======== 0 1 ========
#      ======== 0 3 ========
#      ======== 0 4 ========
#      ======== 2 3 ========
#      ======== 2 4 ========
# ======== 6 -th iteration ========
#      ======== 0 1 ========
#      ======== 0 3 ========
#      ======== 0 4 ========
#      ======== 2 3 ========
#      ======== 2 4 ========
# ======== 7 -th iteration ========
#      ======== 0 1 ========
#      ======== 0 3 ========
#      ======== 0 4 ========
#      ======== 2 3 ========
#      ======== 2 4 ========
# ======== 8 -th iteration ========
#      ======== 0 1 ========
#      ======== 0 3 ========
#      ======== 0 4 ========
#      ======== 2 3 ========
#      ======== 2 4 ========
# ======== 9 -th iteration ========
#      ======== 0 1 ========
#      ======== 0 3 ========
#      ======== 0 4 ========
#      ======== 2 3 ========
#      ======== 2 4 ========
# ======== 10 -th iteration ========
#      ======== 0 1 ========
#      ======== 0 3 ========
#      ======== 0 4 ========
#      ======== 2 3 ========
#      ======== 2 4 ========
# ======== 11 -th iteration ========
#      ======== 0 1 ========
#      ======== 0 3 ========
#      ======== 0 4 ========
#      ======== 2 3 ========
#      ======== 2 4 ========
# ======== original ========
#               動画時間_correct   視聴回数   コメント  高評価件数  低評価件数
# 動画時間_correct        1.0000 0.3289 0.4521 0.4101 0.1251
# 視聴回数                0.3289 1.0000 0.8486 0.9104 0.8311
# コメント                0.4521 0.8486 1.0000 0.8322 0.6137
# 高評価件数               0.4101 0.9104 0.8322 1.0000 0.6606
# 低評価件数               0.1251 0.8311 0.6137 0.6606 1.0000
# ======== estimated ========
#               動画時間_correct   視聴回数   コメント  高評価件数  低評価件数
# 動画時間_correct        1.0000 0.3839 0.4521 0.3495 0.3191
# 視聴回数                0.3839 1.0000 0.8486 0.9104 0.8311
# コメント                0.4521 0.8486 1.0000 0.7725 0.7053
# 高評価件数               0.3495 0.9104 0.7725 1.0000 0.6606
# 低評価件数               0.3191 0.8311 0.7053 0.6606 1.0000
# ======== test rel to original ========
# dev: 1.026833932469935
# p: 0.9603725230426291
# ======== test rel to prev ========
# dev: 0.5100436249915319
# p: 0.4751199717690303

# %%
print('inverse of correlation')
pd.DataFrame(inverse_cor(estimated_cors[-1]), index=column_names, columns=column_names)
# Out:
# inverse of correlation
#               動画時間_correct    視聴回数    コメント   高評価件数   低評価件数
# 動画時間_correct        1.0000 -0.0003 -0.2586  0.0001  0.0000
# 視聴回数               -0.0003  1.0000 -0.3939 -0.7903 -0.6753
# コメント               -0.2586 -0.3939  1.0000  0.0000 -0.0000
# 高評価件数               0.0001 -0.7903  0.0000  1.0000  0.4176
# 低評価件数               0.0000 -0.6753 -0.0000  0.4176  1.0000

# %%
print('partial correlation')
pd.DataFrame(inverse_cor(estimated_cors[-1]), index=column_names, columns=column_names).applymap(lambda x: -x/(1 + x**2) if x < 1-1e-4 else 1)
# Out:
# partial correlation
#               動画時間_correct   視聴回数    コメント   高評価件数   低評価件数
# 動画時間_correct        1.0000 0.0003  0.2424 -0.0001 -0.0000
# 視聴回数                0.0003 1.0000  0.3410  0.4865  0.4638
# コメント                0.2424 0.3410  1.0000 -0.0000  0.0000
# 高評価件数              -0.0001 0.4865 -0.0000  1.0000 -0.3556
# 低評価件数              -0.0000 0.4638  0.0000 -0.3556  1.0000
